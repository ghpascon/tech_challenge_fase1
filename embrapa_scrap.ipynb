# %% [markdown]
# # TESTAR WEBSCRAPPING COM BS4

# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_json(soup):
    # Pegando título e ano
    p_tag = soup.find("p", class_="text_center")
    text = p_tag.get_text(strip=True)
    titulo = text[:text.index('[')].strip()
    ano = int(text[text.index('[')+1:text.index(']')])
    
    #pegando dados da tabela
    table = soup.find("table", class_="tb_base tb_dados")
    dados = []
    item = {}
    for row in table.find_all("tr")[1:]:  # pula o header
        cols = row.find_all("td")
        classe = cols[0].get('class')
        qtd = cols[1].text.strip().replace('.','').replace('-','0')
        qtd = int(qtd)
        if classe is not None and classe[0] == 'tb_item':
            if not item == {}:
                dados.append(item)
                item = {}
            item["item"] = cols[0].text.strip()
            item["qtd"] = [{'total':qtd}]
        if classe is not None and classe[0] == 'tb_subitem':
            item["qtd"].append({
                cols[0].text.strip(): qtd,
            })
    if not item == {}:
        dados.append(item)        
    dados
    tfoot = table.find("tfoot", class_="tb_total")
    tds = tfoot.find_all("td")
    total = int(tds[1].text.strip().replace('.','').replace('-','0'))

    json = {
        "titulo":titulo,
        "ano":ano,
        "total":total,
        "tipo":dados
    }
    return json

# %%
def get_json2(soup):
    # Pegando título e ano
    p_tag = soup.find("p", class_="text_center")
    text = p_tag.get_text(strip=True)
    titulo = text[:text.index('[')].strip()
    ano = int(text[text.index('[')+1:text.index(']')])
    
    #pegando dados da tabela
    table = soup.find("table", class_="tb_base tb_dados")
    dados = []
    item = {}
    for row in table.find_all("tr")[1:]:  # pula o header
        cols = row.find_all("td")
        item["pais"]=cols[0].text.strip()
        item["qtd"]=int(cols[1].text.strip().replace('.','').replace('-','0'))
        item["valor"]=int(cols[2].text.strip().replace('.','').replace('-','0'))
        dados.append(item)
        item = {}
    
    tfoot = table.find("tfoot", class_="tb_total")
    tds = tfoot.find_all("td")
    total = int(tds[1].text.strip().replace('.','').replace('-','0'))

    json = {
        "titulo":titulo,
        "ano":ano,
        "total":total,
        "tipo":dados
    }
    return json

# %% [markdown]
# ## PRODUCAO

# %%
# Ano: [1970-2023]
ano = 2023

# %%
url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_02"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!-- versão 2.00 -->
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# <head>
# <meta charset="utf-8"/>
# <meta content="Na página 'Vitibrasil' são apresentadas informações referentes à quantidade de uvas processadas, produção e comercialização de vinhos, suco e derivados provenientes do Estado do Rio Grande do Sul, que representa mais de 90% da produção nacional. Também são apresentados os dados de importações e exportações dos produtos da vitivinicultura." name="description"/>
# <meta content="Vinhos, Espumante, Uva, Uvas passas, Suco de uva, Produção, Processamento, Comercialização, Importação, Exportação, Publicação" lang="pt-BR" name="keywords"/>
# <meta content="Embrapa Uva e Vinho" name="author"/>
# <link href="./figures/favicon.ico" rel="Shortcut Icon"/>
# <link href="vitibrasil.css" rel="stylesheet" type="text/css"/>
# <title>Banco de dados de uva, vinho e derivados</title>
# <script>
#     var x = screen.width;
#     window.onload = function() {
#       var meta = document.createElement('meta');
#       meta.name = "viewport";
#       if(x < 780) {
#         var val = x/780;
#         meta.content = 'width=device-width, initial-scale=' + val;
#       }
#       else {
#         meta.content = 'width=device-width, initial-scale=1.0';
#       }
#       document.getElementsByTagName('head')[0].appendChild(meta);
#     }
#   </script>
# <!-- Piwik -->
# <script type="text/javascript">
#     var _paq = _paq || [];
#     _paq.push(['trackPageView']);
#     _paq.push(['enableLinkTracking']);
#     (function() {
#       var u=(("https:" == document.location.protocol) ? "https" : "http") + "://hotsites.cnpuv.embrapa.br/estatisticas/";
#       _paq.push(['setTrackerUrl', u+'piwik.php']);
#       _paq.push(['setSiteId', 3]);
#       var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript';
#       g.defer=true; g.async=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
#   </script>
# <noscript><p><img alt="" src="http://hotsites.cnpuv.embrapa.br/estatisticas/piwik.php?idsite=3" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </head>
# <body>
# <table class="tb_layout" id="_top">
# <tr>
# <td> </td>
# <td class="col_center" id="td_center">
# <table class="tb_base">
# <tr>
# <td>
# <p id="program_title">Dados da Vitivinicultura</p>
# </td>
# <td>
# <p id="program_mail">
# <a href="mailto:loiva.mello@embrapa.br">Loiva Maria Ribeiro de Mello</a>
# <br/>
# <a href="mailto:carlos.machado@embrapa.br">Carlos Alberto Ely Machado</a>
# </p>
# </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_layout">
# <tr>
# <td id="tb_banner"></td>
# </tr>
# </table>
# <table class="tb_layout no_print">
# <tr>
# <td> </td>
# <td class="col_center" id="row_height">
# <form action="index.php" method="get">
# <p id="row_btn">
# <button class="btn_opt" name="opcao" type="submit" value="opt_01">Apresentação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_02">Produção</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_03">Processamento</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_04">Comercialização</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_05">Importação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_06">Exportação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_07">Publicação</button>
# </p>
# </form>
# <script>
#             var btn = 'opt_02';
#             var item = document.querySelector('button[value=' + btn + ']');
#             item.setAttribute('id','btn_active');
#           </script>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <div class="div_content">
# <p class="subtitle_1">Banco de dados de uva, vinho e derivados</p>
# <p class="subtitle_2">Produção de vinhos, sucos e derivados do Rio Grande do Sul</p>
# <table class="tb_base tb_header no_print">
# <tr>
# <td>
#
#         </td>
# <td>
# <form action="index.php">
# <p id="p_navegano">
# <button name="ano" type="submit" value="1970">«</button>
# <button name="ano" onclick="if(this.value&lt;1970){this.value=1970}" type="submit" value="2022">‹</button>
# <button disabled="disabled" id="neutral"> </button>
# <button name="ano" onclick="if(this.value&gt;2023){this.value=2023}" type="submit" value="2024">›</button>
# <button name="ano" type="submit" value="2023">»</button>
# <input name="opcao" type="hidden" value="opt_02"/>
# </p>
# </form>
# </td>
# <td>
# <form action="index.php">
# <p id="p_ano">
# <label class="lbl_pesq">Ano: [1970-2023] </label> <br/>
# <input autocomplete="off" class="text_pesq" max="2023" min="1970" name="ano" onkeydown="return event.keyCode !== 69" required="" type="number" value=""/>
#               <input class="subm_pesq" type="submit" value="Ok"/>
# <input name="opcao" type="hidden" value="opt_02"/>
# </p>
# </form>
# </td>
# </tr>
# </table>
# <div class="content_center">
# <p class="text_center"> Produção de vinhos, sucos e derivados  [2023] </p>
# <table class="tb_base tb_dados">
# <thead>
# <tr>
# <th>Produto </th>
# <th>Quantidade (L.) </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tb_item">
#                 VINHO DE MESA
#               </td>
# <td class="tb_item">
#                 169.762.429
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Tinto
#               </td>
# <td class="tb_subitem">
#                 139.320.884
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Branco
#               </td>
# <td class="tb_subitem">
#                 27.910.299
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Rosado
#               </td>
# <td class="tb_subitem">
#                 2.531.246
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 VINHO FINO DE MESA (VINIFERA)
#               </td>
# <td class="tb_item">
#                 46.268.556
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Tinto
#               </td>
# <td class="tb_subitem">
#                 23.615.783
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Branco
#               </td>
# <td class="tb_subitem">
#                 20.693.437
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Rosado
#               </td>
# <td class="tb_subitem">
#                 1.959.336
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 SUCO
#               </td>
# <td class="tb_item">
#                 67.045.238
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Suco de uva integral
#               </td>
# <td class="tb_subitem">
#                 38.122.173
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Suco de uva concentrado
#               </td>
# <td class="tb_subitem">
#                 28.216.760
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Suco de uva adoçado
#               </td>
# <td class="tb_subitem">
#                 94.587
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Suco de uva orgânico
#               </td>
# <td class="tb_subitem">
#                 611.718
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Suco de uva reconstituído
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 DERIVADOS
#               </td>
# <td class="tb_item">
#                 174.716.647
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Espumante
#               </td>
# <td class="tb_subitem">
#                 65.525
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Espumante moscatel
#               </td>
# <td class="tb_subitem">
#                 14.744
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Base espumante
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Base espumante moscatel
#               </td>
# <td class="tb_subitem">
#                 6.734.590
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Base Champenoise champanha
#               </td>
# <td class="tb_subitem">
#                 1.552.243
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Base Charmat champanha
#               </td>
# <td class="tb_subitem">
#                 5.418.118
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Bebida de uva
#               </td>
# <td class="tb_subitem">
#                 1.627
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Polpa de uva
#               </td>
# <td class="tb_subitem">
#                 1.388.251
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Mosto simples
#               </td>
# <td class="tb_subitem">
#                 157.848.983
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Mosto concentrado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Mosto de uva com bagaço
#               </td>
# <td class="tb_subitem">
#                 7.784
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Mosto dessulfitado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Mistelas
#               </td>
# <td class="tb_subitem">
#                 600
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Néctar de uva
#               </td>
# <td class="tb_subitem">
#                 70.976
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Licorosos
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Compostos
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Jeropiga
#               </td>
# <td class="tb_subitem">
#                 4.500
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Filtrado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Frisante
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Vinho leve
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Vinho licoroso
#               </td>
# <td class="tb_subitem">
#                 73.600
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Brandy
#               </td>
# <td class="tb_subitem">
#                 450
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Destilado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Bagaceira
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Licor de bagaceira
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Vinagre
#               </td>
# <td class="tb_subitem">
#                 9.000
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Borra líquida
#               </td>
# <td class="tb_subitem">
#                 758.140
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Borra seca
#               </td>
# <td class="tb_subitem">
#                 17.200
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Vinho Composto
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Pisco
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Vinho orgânico
#               </td>
# <td class="tb_subitem">
#                 94.150
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Espumante orgânico
#               </td>
# <td class="tb_subitem">
#                 1.365
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Destilado alcoólico simples de bagaceira
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Vinho acidificado
#               </td>
# <td class="tb_subitem">
#                 2.500
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Mosto parcialmente fermentado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                 Outros derivados
#               </td>
# <td class="tb_subitem">
#                 652.301
#               </td>
# </tr>
# </tbody>
# <tfoot class="tb_total">
# <tr>
# <td>
#             Total
#           </td>
# <td>
#             457.792.870
#           </td>
# </tr>
# </tfoot>
# </table>
# <div class="tb_font">
#       Fonte: União Brasileira de Vitivinicultura - UVIBRA <br/> Elaboração: EMBRAPA/CNPUV <br/>
# </div>
# <table class="tb_base tb_link no_print">
# <tr>
# <td>
# <a class="footer_content" href="download/Producao.csv" target="_blank">
# <img alt="" height="16" src="figures/download.png" width="16"/>
# <span class="spn_small">DOWNLOAD</span>
# </a>
# </td>
# <td class="footer_right">
# <a class="footer_content" href="#_top">
# <img alt="" height="16" src="figures/topo.png" width="16"/>
# <span class="spn_small">TOPO</span>
# </a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <table class="tb_base tb_footer">
# <tr>
# <td>
#                 Copyright © Embrapa Uva e Vinho. Todos os direitos reservados.<br/>
#                 Mais informações: <a class="footer_sac" href="https://www.embrapa.br/fale-conosco/sac">https://www.embrapa.br/fale-conosco/sac</a><br/>
#                 Última modificação: 21/12/23
#               </td>
# <td class="footer_right">
#                 Rua Livramento 515, Caixa Postal 130<br/>
#                 95700-000 Bento Gonçalves, RS - Brasil<br/>
#                 Fone: (54) 3455-8000 - Fax: (54) 3451-2792
#               </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# </body>
# </html>

# %%
get_json(soup)
# Out:
# {'titulo': 'Produção de vinhos, sucos e derivados',
#  'ano': 2023,
#  'total': 457792870,
#  'tipo': [{'item': 'VINHO DE MESA',
#    'qtd': [{'total': 169762429},
#     {'Tinto': 139320884},
#     {'Branco': 27910299},
#     {'Rosado': 2531246}]},
#   {'item': 'VINHO FINO DE MESA (VINIFERA)',
#    'qtd': [{'total': 46268556},
#     {'Tinto': 23615783},
#     {'Branco': 20693437},
#     {'Rosado': 1959336}]},
#   {'item': 'SUCO',
#    'qtd': [{'total': 67045238},
#     {'Suco de uva integral': 38122173},
#     {'Suco de uva concentrado': 28216760},
#     {'Suco de uva adoçado': 94587},
#     {'Suco de uva orgânico': 611718},
#     {'Suco de uva reconstituído': 0}]},
#   {'item': 'DERIVADOS',
#    'qtd': [{'total': 174716647},
#     {'Espumante': 65525},
#     {'Espumante moscatel': 14744},
#     {'Base espumante': 0},
#     {'Base espumante moscatel': 6734590},
#     {'Base Champenoise champanha': 1552243},
#     {'Base Charmat champanha': 5418118},
#     {'Bebida de uva': 1627},
#     {'Polpa de uva': 1388251},
#     {'Mosto simples': 157848983},
#     {'Mosto concentrado': 0},
#     {'Mosto de uva com bagaço': 7784},
#     {'Mosto dessulfitado': 0},
#     {'Mistelas': 600},
#     {'Néctar de uva': 70976},
#     {'Licorosos': 0},
#     {'Compostos': 0},
#     {'Jeropiga': 4500},
#     {'Filtrado': 0},
#     {'Frisante': 0},
#     {'Vinho leve': 0},
#     {'Vinho licoroso': 73600},
#     {'Brandy': 450},
#     {'Destilado': 0},
#     {'Bagaceira': 0},
#     {'Licor de bagaceira': 0},
#     {'Vinagre': 9000},
#     {'Borra líquida': 758140},
#     {'Borra seca': 17200},
#     {'Vinho Composto': 0},
#     {'Pisco': 0},
#     {'Vinho orgânico': 94150},
#     {'Espumante orgânico': 1365},
#     {'Destilado alcoólico simples de bagaceira': 0},
#     {'Vinho acidificado': 2500},
#     {'Mosto parcialmente fermentado': 0},
#     {'Outros derivados': 652301}]}]}

# %% [markdown]
# ## PROCESSAMENTO

# %%
# Ano: [1970-2023]
ano = 2023

# %%
soups = []
for i in range(1,5):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_03&subopcao=subopt_0{i}"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")
    soups.append(soup)
soups[2]
# Out:
# <!-- versão 2.00 -->
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# <head>
# <meta charset="utf-8"/>
# <meta content="Na página 'Vitibrasil' são apresentadas informações referentes à quantidade de uvas processadas, produção e comercialização de vinhos, suco e derivados provenientes do Estado do Rio Grande do Sul, que representa mais de 90% da produção nacional. Também são apresentados os dados de importações e exportações dos produtos da vitivinicultura." name="description"/>
# <meta content="Vinhos, Espumante, Uva, Uvas passas, Suco de uva, Produção, Processamento, Comercialização, Importação, Exportação, Publicação" lang="pt-BR" name="keywords"/>
# <meta content="Embrapa Uva e Vinho" name="author"/>
# <link href="./figures/favicon.ico" rel="Shortcut Icon"/>
# <link href="vitibrasil.css" rel="stylesheet" type="text/css"/>
# <title>Banco de dados de uva, vinho e derivados</title>
# <script>
#     var x = screen.width;
#     window.onload = function() {
#       var meta = document.createElement('meta');
#       meta.name = "viewport";
#       if(x < 780) {
#         var val = x/780;
#         meta.content = 'width=device-width, initial-scale=' + val;
#       }
#       else {
#         meta.content = 'width=device-width, initial-scale=1.0';
#       }
#       document.getElementsByTagName('head')[0].appendChild(meta);
#     }
#   </script>
# <!-- Piwik -->
# <script type="text/javascript">
#     var _paq = _paq || [];
#     _paq.push(['trackPageView']);
#     _paq.push(['enableLinkTracking']);
#     (function() {
#       var u=(("https:" == document.location.protocol) ? "https" : "http") + "://hotsites.cnpuv.embrapa.br/estatisticas/";
#       _paq.push(['setTrackerUrl', u+'piwik.php']);
#       _paq.push(['setSiteId', 3]);
#       var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript';
#       g.defer=true; g.async=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
#   </script>
# <noscript><p><img alt="" src="http://hotsites.cnpuv.embrapa.br/estatisticas/piwik.php?idsite=3" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </head>
# <body>
# <table class="tb_layout" id="_top">
# <tr>
# <td> </td>
# <td class="col_center" id="td_center">
# <table class="tb_base">
# <tr>
# <td>
# <p id="program_title">Dados da Vitivinicultura</p>
# </td>
# <td>
# <p id="program_mail">
# <a href="mailto:loiva.mello@embrapa.br">Loiva Maria Ribeiro de Mello</a>
# <br/>
# <a href="mailto:carlos.machado@embrapa.br">Carlos Alberto Ely Machado</a>
# </p>
# </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_layout">
# <tr>
# <td id="tb_banner"></td>
# </tr>
# </table>
# <table class="tb_layout no_print">
# <tr>
# <td> </td>
# <td class="col_center" id="row_height">
# <form action="index.php" method="get">
# <p id="row_btn">
# <button class="btn_opt" name="opcao" type="submit" value="opt_01">Apresentação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_02">Produção</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_03">Processamento</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_04">Comercialização</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_05">Importação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_06">Exportação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_07">Publicação</button>
# </p>
# </form>
# <script>
#             var btn = 'opt_03';
#             var item = document.querySelector('button[value=' + btn + ']');
#             item.setAttribute('id','btn_active');
#           </script>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <div class="div_content">
# <p class="subtitle_1">Banco de dados de uva, vinho e derivados</p>
# <p class="subtitle_2">Quantidade de uvas processadas no Rio Grande do Sul</p>
# <table class="tb_base tb_header no_print">
# <tr>
# <td>
# <form action="index.php" method="get">
# <p>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_01">Viníferas</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_02">Americanas e híbridas</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_03">Uvas de mesa</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_04">Sem classificação</button><br/>
# <input name="opcao" type="hidden" value="opt_03"/>
# </p>
# </form>
# <script>
#             var btn1 = 'subopt_03';
#             var item1 = document.querySelector('button[value=' + btn1 + ']');
#             item1.setAttribute('id','btn1_active');
#           </script>
# </td>
# <td>
# <form action="index.php">
# <p id="p_navegano">
# <button name="ano" type="submit" value="1970">«</button>
# <button name="ano" onclick="if(this.value&lt;1970){this.value=1970}" type="submit" value="2022">‹</button>
# <button disabled="disabled" id="neutral"> </button>
# <button name="ano" onclick="if(this.value&gt;2023){this.value=2023}" type="submit" value="2024">›</button>
# <button name="ano" type="submit" value="2023">»</button>
# <input name="opcao" type="hidden" value="opt_03"/>
# <input name="subopcao" type="hidden" value="subopt_03"/>
# </p>
# </form>
# </td>
# <td>
# <form action="index.php">
# <p id="p_ano">
# <label class="lbl_pesq">Ano: [1970-2023] </label> <br/>
# <input autocomplete="off" class="text_pesq" max="2023" min="1970" name="ano" onkeydown="return event.keyCode !== 69" required="" type="number" value=""/>
#               <input class="subm_pesq" type="submit" value="Ok"/>
# <input name="opcao" type="hidden" value="opt_03"/>
# <input name="subopcao" type="hidden" value="subopt_03"/>
# </p>
# </form>
# </td>
# </tr>
# </table>
# <div class="content_center">
# <p class="text_center"> Uvas de mesa processadas [2023] </p>
# <table class="tb_base tb_dados">
# <thead>
# <tr>
# <th>Cultivar </th>
# <th>Quantidade (Kg) </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tb_item">
#                 TINTAS
#               </td>
# <td class="tb_item">
#                 175.030
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Alphonse Lavallee
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Moscato de Hamburgo
#               </td>
# <td class="tb_subitem">
#                 175.030
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 BRANCAS
#               </td>
# <td class="tb_item">
#                 13.440
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Cardinal
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Golden Queen
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Patrícia
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Perlona
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Italia
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                  Rubi (Itália, Itália Ro)
#               </td>
# <td class="tb_subitem">
#                 13.440
#               </td>
# </tr>
# </tbody>
# <tfoot class="tb_total">
# <tr>
# <td>
#             Total
#           </td>
# <td>
#             188.470
#           </td>
# </tr>
# </tfoot>
# </table>
# <div class="tb_font">
#       Fonte: Secretaria da Agricultura, Pecuária e Desenvolvimento Rural <br/> Elaboração: EMBRAPA/CNPUV <br/>
# </div>
# <table class="tb_base tb_link no_print">
# <tr>
# <td>
# <a class="footer_content" href="download/ProcessaMesa.csv" target="_blank">
# <img alt="" height="16" src="figures/download.png" width="16"/>
# <span class="spn_small">DOWNLOAD</span>
# </a>
# </td>
# <td class="footer_right">
# <a class="footer_content" href="#_top">
# <img alt="" height="16" src="figures/topo.png" width="16"/>
# <span class="spn_small">TOPO</span>
# </a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <table class="tb_base tb_footer">
# <tr>
# <td>
#                 Copyright © Embrapa Uva e Vinho. Todos os direitos reservados.<br/>
#                 Mais informações: <a class="footer_sac" href="https://www.embrapa.br/fale-conosco/sac">https://www.embrapa.br/fale-conosco/sac</a><br/>
#                 Última modificação: 21/12/23
#               </td>
# <td class="footer_right">
#                 Rua Livramento 515, Caixa Postal 130<br/>
#                 95700-000 Bento Gonçalves, RS - Brasil<br/>
#                 Fone: (54) 3455-8000 - Fax: (54) 3451-2792
#               </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# </body>
# </html>

# %%
json = {}
total = 0
for soup in soups:
    current_json = get_json(soup)
    total += current_json["total"]
    json[current_json["titulo"]] = current_json
json["total"]=total
json
# Out:
# {'Uvas viníferas processadas [2023]': {'titulo': 'Uvas viníferas processadas [2023]',
#   'total': 99557416,
#   'tipo': [{'item': 'TINTAS',
#     'qtd': [{'total': 35881118},
#      {'Alicante Bouschet': 4108858},
#      {'Ancelota': 783688},
#      {'Aramon': 0},
#      {'Alfrocheiro': 0},
#      {'Arinarnoa': 147979},
#      {'Aspirant Bouschet': 138338},
#      {'Barbera': 35292},
#      {'Bonarda': 7800},
#      {'Cabernet Franc': 2152213},
#      {'Cabernet Sauvignon': 5917173},
#      {'Caladoc': 8310},
#      {'Campanario': 0},
#      {'Canaiolo': 0},
#      {'Carignan': 0},
#      {'Carmenere': 14360},
#      {'Castelão': 0},
#      {'Corvina': 2200},
#      {'Croatina': 0},
#      {'Cinsaut': 0},
#      {'Dom Felder': 0},
#      {'Dolcetto': 0},
#      {'Durif': 0},
#      {'Egiodola': 1439540},
#      {'Ekigaina': 1000},
#      {'Festival (Sugraone)': 0},
#      {'Franconia': 0},
#      {'Freisa': 0},
#      {'Gamay St Romain': 0},
#      {'Gamay Beaujolais': 126667},
#      {'Grand Noir': 0},
#      {'Grenache': 830},
#      {'Jaen': 0},
#      {'Lagrein': 3100},
#      {'Lambrusco': 15620},
#      {'Malbec': 584141},
#      {'Marzemina': 390},
#      {'Merlot': 7179442},
#      {'Marselan': 988860},
#      {'Mistura de uvas viníferas tinto': 700},
#      {'Molinera': 2600},
#      {'Montepulciano': 42503},
#      {'Moscato Bailey': 170188},
#      {'Napa Gamay': 0},
#      {'Nebbiolo': 26788},
#      {'Petit Verdot': 207896},
#      {'Petite Sirah': 173887},
#      {'Pinotage': 397456},
#      {'Pinot Noir': 4182135},
#      {'Pinot Saint George': 5060},
#      {'Piriquita': 0},
#      {'Primitivo': 1650},
#      {'Rebo': 330784},
#      {'Refosco': 0},
#      {'Rondinella': 5280},
#      {'Ruby Cabernet': 163069},
#      {'Sangiovese': 92540},
#      {'Saperavi': 13323},
#      {'Sira (falsa)': 0},
#      {'Tannat': 5712207},
#      {'Tempranillo': 375165},
#      {'Teroldego': 123714},
#      {'Torrontes': 23500},
#      {'Tinta Barroca': 0},
#      {'Tinta Roriz': 3006},
#      {'Touriga Francesa': 0},
#      {'Touriga Nacional': 171866},
#      {'Tinta Madeira': 0},
#      {'Tintoria': 0},
#      {'Trincdeira': 0},
#      {'Trousseau': 0},
#      {'Zinfandel': 0},
#      {'Outras1': 0}]},
#    {'item': 'BRANCAS E ROSADAS',
#     'qtd': [{'total': 63676298},
#      {'Aliatico': 0},
#      {'Aligote': 0},
#      {'Altesse': 0},
#      {'Alvarinho': 150467},
#      {'Arriloba': 0},
#      {'Auxerrois': 0},
#      {'Burger': 0},
#      {'Chardonnay': 8315602},
#      {'Chasselas': 0},
#      {'Chenin Blanc': 298406},
#      {'Clairette(1)': 0},
#      {'Colombard': 374903},
#      {'Flora': 0},
#      {'Garganega': 400},
#      {'Gewurztraminer': 239070},
#      {'Gouveio': 0},
#      {'Gros Manseng': 4510},
#      {'Italia (Pirovano 65) (PE)': 10350},
#      {'Maccabeo': 0},
#      {'Malvasia': 0},
#      {'Malvasia Amarela': 67467},
#      {'Malvasia Bianca': 80786},
#      {'Malvasia Chianti': 0},
#      {'Malvasia Verde': 46510},
#      {'Malvasia di Candia': 6869071},
#      {'Malvasia Istriana': 0},
#      {'Mistura de uvas viníferas branco': 41078},
#      {'Mistura de uvas viníferas rosado': 1100},
#      {'Moscato Branco': 20657082},
#      {'Moscato Canelli': 351555},
#      {'Moscato Giallo': 3111774},
#      {'Moscato Nazareno': 504982},
#      {'Moscato Bianco R2': 1211053},
#      {'Moscato de Alexandria': 404111},
#      {'Moscato Rosado': 900},
#      {'Muscat à Petits Grains': 6000},
#      {'Muller Thurgau': 0},
#      {'Muscadelle': 0},
#      {'Ora': 0},
#      {'Palomino': 0},
#      {'Petit Manseng': 3915},
#      {'Peverella': 45898},
#      {'Pinot Blanc': 1310},
#      {'Pinot Gris': 178683},
#      {'Prosecco': 7856146},
#      {'Red Veltliner': 0},
#      {'Riesling Italico': 4642666},
#      {'Riesling Renano': 126736},
#      {'Sauvignon Blanc(2)': 818122},
#      {'Sauvignon Gris': 0},
#      {'Seara Nova': 0},
#      {'Semillon': 112905},
#      {'Schonburger': 12687},
#      {'Sylvaner': 2342},
#      {'Tocai Friulano': 6150},
#      {'Trebbiano': 5954818},
#      {'Trebbiano Toscano': 139845},
#      {'Verdea': 0},
#      {'Verdelho': 2080},
#      {'Verdiso': 0},
#      {'Vermentino': 28218},
#      {'Vernaccia': 800},
#      {'Viogner': 21794},
#      {'Viognier': 974005},
#      {'Outras(3)': 0}]}]},
#  'Uvas americanas e híbridas processadas [2023]': {'titulo': 'Uvas americanas e híbridas processadas [2023]',
#   'total': 565243922,
#   'tipo': [{'item': 'TINTAS',
#     'qtd': [{'total': 502666358},
#      {'Bacarina': 0},
#      {'Bailey': 587066},
#      {'Bordo': 154310837},
#      {'Bourdin (S)': 0},
#      {'BRS Carmen': 22242535},
#      {'BRS Cora': 19508450},
#      {'BRS Magna': 13919693},
#      {'BRS Margot': 36842},
#      {'BRS Morena': 0},
#      {'BRS Núbia': 57060},
#      {'BRS Rúbea': 3311843},
#      {'BRS Violeta': 15657282},
#      {'BRS Vitória': 8820},
#      {'Champagnon (Champanheta)': 0},
#      {'Coleções': 0},
#      {'Concord': 25091503},
#      {'Concord clone 30': 5491777},
#      {'Couderc': 23121275},
#      {'Cynthiana(1)': 1186253},
#      {'Herbemont': 1417502},
#      {'IAC 138022': 0},
#      {'Isabel': 176590596},
#      {'Isabel Precoce': 17956434},
#      {'Jacquez': 12749029},
#      {'Kyoko': 0},
#      {'Landot': 0},
#      {'Mistura de uvas americanas tinto': 346747},
#      {'Oberlin': 0},
#      {'Othello': 0},
#      {'Paco': 15300},
#      {'Patricia': 0},
#      {'Seibel': 2600315},
#      {'Seibel 2 (seibeleto)': 5387790},
#      {'Seyve Willard (Tinta)': 1002782},
#      {'Vênus': 68626}]},
#    {'item': 'BRANCAS E ROSADAS',
#     'qtd': [{'total': 62577564},
#      {'Baco': 0},
#      {'Bokay': 84670},
#      {'BRS Bibiana': 25491},
#      {'BRS Clara': 0},
#      {'BRS Lorena': 10186931},
#      {'Couderc 13': 4524468},
#      {'Delaware': 0},
#      {'Dona Zillá': 24890},
#      {'Dut Chess': 0},
#      {'Goethe': 269143},
#      {'IAC': 0},
#      {'Juliana': 0},
#      {'Martha': 1380},
#      {'Mistura de uvas americanas': 42550},
#      {'Moscato Embrapa': 8790794},
#      {'Niagara': 0},
#      {'Niagara Branca': 23148433},
#      {'Niagara Rosada': 14987968},
#      {'Poloske': 55493},
#      {'Seleções': 0},
#      {'Seyve Villard': 0},
#      {'Seyve Villard 5276': 105771},
#      {'Seyve Villard 12375': 329582},
#      {'Tardia de Caxias': 0},
#      {'Outras(2)': 0}]}]},
#  'Uvas de mesa processadas [2023]': {'titulo': 'Uvas de mesa processadas [2023]',
#   'total': 188470,
#   'tipo': [{'item': 'TINTAS',
#     'qtd': [{'total': 175030},
#      {'Alphonse Lavallee': 0},
#      {'Moscato de Hamburgo': 175030}]},
#    {'item': 'BRANCAS',
#     'qtd': [{'total': 13440},
#      {'Cardinal': 0},
#      {'Golden Queen': 0},
#      {'Patrícia': 0},
#      {'Perlona': 0},
#      {'Italia': 0},
#      {'Rubi (Itália, Itália Ro)': 13440}]}]},
#  'Uvas sem classificação processadas [2023]': {'titulo': 'Uvas sem classificação processadas [2023]',
#   'total': 0,
#   'tipo': [{'item': 'Sem classificação', 'qtd': [{'total': 0}]}]},
#  'total': 664989808}

# %%
print([x for x in json])
# Out:
# ['Uvas viníferas processadas [2023]', 'Uvas americanas e híbridas processadas [2023]', 'Uvas de mesa processadas [2023]', 'Uvas sem classificação processadas [2023]', 'total']

# %% [markdown]
# ## COMERCIALIZACAO

# %%
# Ano: [1970-2023]
ano = 2023

# %%
url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_04"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!-- versão 2.00 -->
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# <head>
# <meta charset="utf-8"/>
# <meta content="Na página 'Vitibrasil' são apresentadas informações referentes à quantidade de uvas processadas, produção e comercialização de vinhos, suco e derivados provenientes do Estado do Rio Grande do Sul, que representa mais de 90% da produção nacional. Também são apresentados os dados de importações e exportações dos produtos da vitivinicultura." name="description"/>
# <meta content="Vinhos, Espumante, Uva, Uvas passas, Suco de uva, Produção, Processamento, Comercialização, Importação, Exportação, Publicação" lang="pt-BR" name="keywords"/>
# <meta content="Embrapa Uva e Vinho" name="author"/>
# <link href="./figures/favicon.ico" rel="Shortcut Icon"/>
# <link href="vitibrasil.css" rel="stylesheet" type="text/css"/>
# <title>Banco de dados de uva, vinho e derivados</title>
# <script>
#     var x = screen.width;
#     window.onload = function() {
#       var meta = document.createElement('meta');
#       meta.name = "viewport";
#       if(x < 780) {
#         var val = x/780;
#         meta.content = 'width=device-width, initial-scale=' + val;
#       }
#       else {
#         meta.content = 'width=device-width, initial-scale=1.0';
#       }
#       document.getElementsByTagName('head')[0].appendChild(meta);
#     }
#   </script>
# <!-- Piwik -->
# <script type="text/javascript">
#     var _paq = _paq || [];
#     _paq.push(['trackPageView']);
#     _paq.push(['enableLinkTracking']);
#     (function() {
#       var u=(("https:" == document.location.protocol) ? "https" : "http") + "://hotsites.cnpuv.embrapa.br/estatisticas/";
#       _paq.push(['setTrackerUrl', u+'piwik.php']);
#       _paq.push(['setSiteId', 3]);
#       var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript';
#       g.defer=true; g.async=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
#   </script>
# <noscript><p><img alt="" src="http://hotsites.cnpuv.embrapa.br/estatisticas/piwik.php?idsite=3" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </head>
# <body>
# <table class="tb_layout" id="_top">
# <tr>
# <td> </td>
# <td class="col_center" id="td_center">
# <table class="tb_base">
# <tr>
# <td>
# <p id="program_title">Dados da Vitivinicultura</p>
# </td>
# <td>
# <p id="program_mail">
# <a href="mailto:loiva.mello@embrapa.br">Loiva Maria Ribeiro de Mello</a>
# <br/>
# <a href="mailto:carlos.machado@embrapa.br">Carlos Alberto Ely Machado</a>
# </p>
# </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_layout">
# <tr>
# <td id="tb_banner"></td>
# </tr>
# </table>
# <table class="tb_layout no_print">
# <tr>
# <td> </td>
# <td class="col_center" id="row_height">
# <form action="index.php" method="get">
# <p id="row_btn">
# <button class="btn_opt" name="opcao" type="submit" value="opt_01">Apresentação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_02">Produção</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_03">Processamento</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_04">Comercialização</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_05">Importação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_06">Exportação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_07">Publicação</button>
# </p>
# </form>
# <script>
#             var btn = 'opt_04';
#             var item = document.querySelector('button[value=' + btn + ']');
#             item.setAttribute('id','btn_active');
#           </script>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <div class="div_content">
# <p class="subtitle_1">Banco de dados de uva, vinho e derivados</p>
# <p class="subtitle_2">Comercialização de vinhos e derivados no Rio Grande do Sul</p>
# <table class="tb_base tb_header no_print">
# <tr>
# <td>
#
#         </td>
# <td>
# <form action="index.php">
# <p id="p_navegano">
# <button name="ano" type="submit" value="1970">«</button>
# <button name="ano" onclick="if(this.value&lt;1970){this.value=1970}" type="submit" value="2022">‹</button>
# <button disabled="disabled" id="neutral"> </button>
# <button name="ano" onclick="if(this.value&gt;2023){this.value=2023}" type="submit" value="2024">›</button>
# <button name="ano" type="submit" value="2023">»</button>
# <input name="opcao" type="hidden" value="opt_04"/>
# </p>
# </form>
# </td>
# <td>
# <form action="index.php">
# <p id="p_ano">
# <label class="lbl_pesq">Ano: [1970-2023] </label> <br/>
# <input autocomplete="off" class="text_pesq" max="2023" min="1970" name="ano" onkeydown="return event.keyCode !== 69" required="" type="number" value=""/>
#               <input class="subm_pesq" type="submit" value="Ok"/>
# <input name="opcao" type="hidden" value="opt_04"/>
# </p>
# </form>
# </td>
# </tr>
# </table>
# <div class="content_center">
# <p class="text_center"> Comercialização de vinhos e derivados  [2023] </p>
# <table class="tb_base tb_dados">
# <thead>
# <tr>
# <th>Produto </th>
# <th>Quantidade (L.) </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tb_item">
#                 VINHO DE MESA
#               </td>
# <td class="tb_item">
#                 187.016.848
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Tinto
#               </td>
# <td class="tb_subitem">
#                 165.097.539
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Rosado
#               </td>
# <td class="tb_subitem">
#                 2.520.748
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Branco
#               </td>
# <td class="tb_subitem">
#                 19.398.561
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 VINHO FINO DE MESA
#               </td>
# <td class="tb_item">
#                 18.589.310
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Tinto
#               </td>
# <td class="tb_subitem">
#                 12.450.606
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Rosado
#               </td>
# <td class="tb_subitem">
#                 1.214.583
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Branco
#               </td>
# <td class="tb_subitem">
#                 4.924.121
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 VINHO FRIZANTE
#               </td>
# <td class="tb_item">
#                 2.843.600
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 VINHO ORGÂNICO
#               </td>
# <td class="tb_item">
#                 9.123
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 VINHO ESPECIAL
#               </td>
# <td class="tb_item">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Tinto
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Rosado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Branco
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 ESPUMANTES
#               </td>
# <td class="tb_item">
#                 29.381.635
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Espumante  Moscatel
#               </td>
# <td class="tb_subitem">
#                 9.771.698
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Espumante
#               </td>
# <td class="tb_subitem">
#                 19.609.379
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Espumante Orgânico
#               </td>
# <td class="tb_subitem">
#                 558
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 SUCO DE UVAS
#               </td>
# <td class="tb_item">
#                 166.708.720
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Suco Natural Integral
#               </td>
# <td class="tb_subitem">
#                 129.419.407
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Suco Adoçado
#               </td>
# <td class="tb_subitem">
#                 128.599
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Suco Reprocessado/reconstituido
#               </td>
# <td class="tb_subitem">
#                 34.402.925
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Suco Orgânico
#               </td>
# <td class="tb_subitem">
#                 932.154
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Outros sucos de uvas
#               </td>
# <td class="tb_subitem">
#                 1.825.635
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 SUCO DE UVAS CONCENTRADO
#               </td>
# <td class="tb_item">
#                 37.852.507
#               </td>
# </tr>
# <tr>
# <td class="tb_item">
#                 OUTROS PRODUTOS COMERCIALIZADOS
#               </td>
# <td class="tb_item">
#                 29.889.342
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Outros vinhos (sem informação detalhada)
#               </td>
# <td class="tb_subitem">
#                 8.152
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Agrin (fermentado, acetico misto)
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Aguardente de vinho 50°gl
#               </td>
# <td class="tb_subitem">
#                 111
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Alcool vinico
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Bagaceira (graspa)
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Base champenoise champanha
#               </td>
# <td class="tb_subitem">
#                 66.290
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Base charmat champanha
#               </td>
# <td class="tb_subitem">
#                 184.040
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Base espumante moscatel
#               </td>
# <td class="tb_subitem">
#                 722.984
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Bebida de uva
#               </td>
# <td class="tb_subitem">
#                 16.780
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Borra líquida
#               </td>
# <td class="tb_subitem">
#                 72.600
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Borra seca
#               </td>
# <td class="tb_subitem">
#                 53.220
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Brandy (conhaque)
#               </td>
# <td class="tb_subitem">
#                 4.506
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Cooler
#               </td>
# <td class="tb_subitem">
#                 4.321.881
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Coquetel com vinho
#               </td>
# <td class="tb_subitem">
#                 397.156
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Destilado de vinho
#               </td>
# <td class="tb_subitem">
#                 245
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Filtrado doce
#               </td>
# <td class="tb_subitem">
#                 2.366.601
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Jeropiga
#               </td>
# <td class="tb_subitem">
#                 346
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Mistelas
#               </td>
# <td class="tb_subitem">
#                 1.668
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Mosto concentrado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Mosto de uva
#               </td>
# <td class="tb_subitem">
#                 359.626
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Mosto sulfitado
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Nectar de uva
#               </td>
# <td class="tb_subitem">
#                 3.604.413
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Outros produtos
#               </td>
# <td class="tb_subitem">
#                 7.459.271
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Polpa de uva
#               </td>
# <td class="tb_subitem">
#                 1.331.651
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Preparado líquido para refresco
#               </td>
# <td class="tb_subitem">
#                 17.178
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Refrigerante +50% suco
#               </td>
# <td class="tb_subitem">
#                 501.876
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Sangria
#               </td>
# <td class="tb_subitem">
#                 84.157
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinagre balsamico
#               </td>
# <td class="tb_subitem">
#                 338.926
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinagre duplo
#               </td>
# <td class="tb_subitem">
#                 1.769.130
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinagre simples
#               </td>
# <td class="tb_subitem">
#                 5.047.280
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinho acetificado
#               </td>
# <td class="tb_subitem">
#                 194.020
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinho base para espumantes
#               </td>
# <td class="tb_subitem">
#                 -
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinho composto
#               </td>
# <td class="tb_subitem">
#                 981
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinho licoroso
#               </td>
# <td class="tb_subitem">
#                 421.974
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinho leve
#               </td>
# <td class="tb_subitem">
#                 132.064
#               </td>
# </tr>
# <tr>
# <td class="tb_subitem">
#                   Vinho gaseificado
#               </td>
# <td class="tb_subitem">
#                 410.215
#               </td>
# </tr>
# </tbody>
# <tfoot class="tb_total">
# <tr>
# <td>
#             Total
#           </td>
# <td>
#             472.291.085
#           </td>
# </tr>
# </tfoot>
# </table>
# <div class="tb_font">
#       Fonte: União Brasileira de Vitivinicultura - UVIBRA <br/> Elaboração: EMBRAPA/CNPUV <br/> Obs: A partir de 1997 houve o desdobramento do item Espumnte em Espumante moscatel e Espumante. <br/> Obs: Em 2007 foi incluido o Vinho Tinto Vinífera do Prêmio de Escoamento da Produção do Governo Federal - PEP <br/>
# </div>
# <table class="tb_base tb_link no_print">
# <tr>
# <td>
# <a class="footer_content" href="download/Comercio.csv" target="_blank">
# <img alt="" height="16" src="figures/download.png" width="16"/>
# <span class="spn_small">DOWNLOAD</span>
# </a>
# </td>
# <td class="footer_right">
# <a class="footer_content" href="#_top">
# <img alt="" height="16" src="figures/topo.png" width="16"/>
# <span class="spn_small">TOPO</span>
# </a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <table class="tb_base tb_footer">
# <tr>
# <td>
#                 Copyright © Embrapa Uva e Vinho. Todos os direitos reservados.<br/>
#                 Mais informações: <a class="footer_sac" href="https://www.embrapa.br/fale-conosco/sac">https://www.embrapa.br/fale-conosco/sac</a><br/>
#                 Última modificação: 21/12/23
#               </td>
# <td class="footer_right">
#                 Rua Livramento 515, Caixa Postal 130<br/>
#                 95700-000 Bento Gonçalves, RS - Brasil<br/>
#                 Fone: (54) 3455-8000 - Fax: (54) 3451-2792
#               </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# </body>
# </html>

# %%
get_json(soup)
# Out:
# {'titulo': 'Comercialização de vinhos e derivados  [2023]',
#  'total': 472291085,
#  'tipo': [{'item': 'VINHO DE MESA',
#    'qtd': [{'total': 187016848},
#     {'Tinto': 165097539},
#     {'Rosado': 2520748},
#     {'Branco': 19398561}]},
#   {'item': 'VINHO FINO DE MESA',
#    'qtd': [{'total': 18589310},
#     {'Tinto': 12450606},
#     {'Rosado': 1214583},
#     {'Branco': 4924121}]},
#   {'item': 'VINHO FRIZANTE', 'qtd': [{'total': 2843600}]},
#   {'item': 'VINHO ORGÂNICO', 'qtd': [{'total': 9123}]},
#   {'item': 'VINHO ESPECIAL',
#    'qtd': [{'total': 0}, {'Tinto': 0}, {'Rosado': 0}, {'Branco': 0}]},
#   {'item': 'ESPUMANTES',
#    'qtd': [{'total': 29381635},
#     {'Espumante  Moscatel': 9771698},
#     {'Espumante': 19609379},
#     {'Espumante Orgânico': 558}]},
#   {'item': 'SUCO DE UVAS',
#    'qtd': [{'total': 166708720},
#     {'Suco Natural Integral': 129419407},
#     {'Suco Adoçado': 128599},
#     {'Suco Reprocessado/reconstituido': 34402925},
#     {'Suco Orgânico': 932154},
#     {'Outros sucos de uvas': 1825635}]},
#   {'item': 'SUCO DE UVAS CONCENTRADO', 'qtd': [{'total': 37852507}]},
#   {'item': 'OUTROS PRODUTOS COMERCIALIZADOS',
#    'qtd': [{'total': 29889342},
#     {'Outros vinhos (sem informação detalhada)': 8152},
#     {'Agrin (fermentado, acetico misto)': 0},
#     {'Aguardente de vinho 50°gl': 111},
#     {'Alcool vinico': 0},
#     {'Bagaceira (graspa)': 0},
#     {'Base champenoise champanha': 66290},
#     {'Base charmat champanha': 184040},
#     {'Base espumante moscatel': 722984},
#     {'Bebida de uva': 16780},
#     {'Borra líquida': 72600},
#     {'Borra seca': 53220},
#     {'Brandy (conhaque)': 4506},
#     {'Cooler': 4321881},
#     {'Coquetel com vinho': 397156},
#     {'Destilado de vinho': 245},
#     {'Filtrado doce': 2366601},
#     {'Jeropiga': 346},
#     {'Mistelas': 1668},
#     {'Mosto concentrado': 0},
#     {'Mosto de uva': 359626},
#     {'Mosto sulfitado': 0},
#     {'Nectar de uva': 3604413},
#     {'Outros produtos': 7459271},
#     {'Polpa de uva': 1331651},
#     {'Preparado líquido para refresco': 17178},
#     {'Refrigerante +50% suco': 501876},
#     {'Sangria': 84157},
#     {'Vinagre balsamico': 338926},
#     {'Vinagre duplo': 1769130},
#     {'Vinagre simples': 5047280},
#     {'Vinho acetificado': 194020},
#     {'Vinho base para espumantes': 0},
#     {'Vinho composto': 981},
#     {'Vinho licoroso': 421974},
#     {'Vinho leve': 132064},
#     {'Vinho gaseificado': 410215}]}]}

# %% [markdown]
# ## IMPORTAÇÃO

# %%
# Ano: [1970-2023]
ano = 2023

# %%
soups = []
for i in range(1,6):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_05&subopcao=subopt_0{i}"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")
    soups.append(soup)
soups[2]
# Out:
# <!-- versão 2.00 -->
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# <head>
# <meta charset="utf-8"/>
# <meta content="Na página 'Vitibrasil' são apresentadas informações referentes à quantidade de uvas processadas, produção e comercialização de vinhos, suco e derivados provenientes do Estado do Rio Grande do Sul, que representa mais de 90% da produção nacional. Também são apresentados os dados de importações e exportações dos produtos da vitivinicultura." name="description"/>
# <meta content="Vinhos, Espumante, Uva, Uvas passas, Suco de uva, Produção, Processamento, Comercialização, Importação, Exportação, Publicação" lang="pt-BR" name="keywords"/>
# <meta content="Embrapa Uva e Vinho" name="author"/>
# <link href="./figures/favicon.ico" rel="Shortcut Icon"/>
# <link href="vitibrasil.css" rel="stylesheet" type="text/css"/>
# <title>Banco de dados de uva, vinho e derivados</title>
# <script>
#     var x = screen.width;
#     window.onload = function() {
#       var meta = document.createElement('meta');
#       meta.name = "viewport";
#       if(x < 780) {
#         var val = x/780;
#         meta.content = 'width=device-width, initial-scale=' + val;
#       }
#       else {
#         meta.content = 'width=device-width, initial-scale=1.0';
#       }
#       document.getElementsByTagName('head')[0].appendChild(meta);
#     }
#   </script>
# <!-- Piwik -->
# <script type="text/javascript">
#     var _paq = _paq || [];
#     _paq.push(['trackPageView']);
#     _paq.push(['enableLinkTracking']);
#     (function() {
#       var u=(("https:" == document.location.protocol) ? "https" : "http") + "://hotsites.cnpuv.embrapa.br/estatisticas/";
#       _paq.push(['setTrackerUrl', u+'piwik.php']);
#       _paq.push(['setSiteId', 3]);
#       var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript';
#       g.defer=true; g.async=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
#   </script>
# <noscript><p><img alt="" src="http://hotsites.cnpuv.embrapa.br/estatisticas/piwik.php?idsite=3" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </head>
# <body>
# <table class="tb_layout" id="_top">
# <tr>
# <td> </td>
# <td class="col_center" id="td_center">
# <table class="tb_base">
# <tr>
# <td>
# <p id="program_title">Dados da Vitivinicultura</p>
# </td>
# <td>
# <p id="program_mail">
# <a href="mailto:loiva.mello@embrapa.br">Loiva Maria Ribeiro de Mello</a>
# <br/>
# <a href="mailto:carlos.machado@embrapa.br">Carlos Alberto Ely Machado</a>
# </p>
# </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_layout">
# <tr>
# <td id="tb_banner"></td>
# </tr>
# </table>
# <table class="tb_layout no_print">
# <tr>
# <td> </td>
# <td class="col_center" id="row_height">
# <form action="index.php" method="get">
# <p id="row_btn">
# <button class="btn_opt" name="opcao" type="submit" value="opt_01">Apresentação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_02">Produção</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_03">Processamento</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_04">Comercialização</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_05">Importação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_06">Exportação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_07">Publicação</button>
# </p>
# </form>
# <script>
#             var btn = 'opt_05';
#             var item = document.querySelector('button[value=' + btn + ']');
#             item.setAttribute('id','btn_active');
#           </script>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <div class="div_content">
# <p class="subtitle_1">Banco de dados de uva, vinho e derivados</p>
# <p class="subtitle_2">Importação de derivados de uva</p>
# <table class="tb_base tb_header no_print">
# <tr>
# <td>
# <form action="index.php" method="get">
# <p>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_01">Vinhos de mesa</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_02">Espumantes</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_03">Uvas frescas</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_04">Uvas passas</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_05">Suco de uva</button>
# <input name="opcao" type="hidden" value="opt_05"/>
# </p>
# </form>
# <script>
#             var btn1 = 'subopt_03';
#             var item1 = document.querySelector('button[value=' + btn1 + ']');
#             item1.setAttribute('id','btn1_active');
#           </script>
# </td>
# <td>
# <form action="index.php">
# <p id="p_navegano">
# <button name="ano" type="submit" value="1970">«</button>
# <button name="ano" onclick="if(this.value&lt;1970){this.value=1970}" type="submit" value="2022">‹</button>
# <button disabled="disabled" id="neutral"> </button>
# <button name="ano" onclick="if(this.value&gt;2024){this.value=2024}" type="submit" value="2024">›</button>
# <button name="ano" type="submit" value="2024">»</button>
# <input name="opcao" type="hidden" value="opt_05"/>
# <input name="subopcao" type="hidden" value="subopt_03"/>
# </p>
# </form>
# </td>
# <td>
# <form action="index.php">
# <p id="p_ano">
# <label class="lbl_pesq">Ano: [1970-2024] </label> <br/>
# <input autocomplete="off" class="text_pesq" max="2024" min="1970" name="ano" onkeydown="return event.keyCode !== 69" required="" type="number" value=""/>
#               <input class="subm_pesq" type="submit" value="Ok"/>
# <input name="opcao" type="hidden" value="opt_05"/>
# <input name="subopcao" type="hidden" value="subopt_03"/>
# </p>
# </form>
# </td>
# </tr>
# </table>
# <div class="content_center">
# <p class="text_center">Importação de uvas frescas [2023] </p>
# <table class="tb_base tb_dados">
# <thead>
# <tr>
# <th>Países</th>
# <th>Quantidade (Kg)</th>
# <th>Valor (US$)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
#             Argélia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Argentina
#           </td>
# <td>
#                     400.781
#                   </td>
# <td>
#                     525.034
#                   </td>
# </tr>
# <tr>
# <td>
#             Brasil
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Chile
#           </td>
# <td>
#                     6.144.949
#                   </td>
# <td>
#                     9.738.753
#                   </td>
# </tr>
# <tr>
# <td>
#             Colômbia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Egito
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Espanha
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Estados Unidos
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Grécia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Itália
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             México
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Peru
#           </td>
# <td>
#                     1.086.032
#                   </td>
# <td>
#                     2.635.488
#                   </td>
# </tr>
# <tr>
# <td>
#             Paraguai
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Portugal
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Panamá
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Reino Unido
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Uruguai
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Venezuela
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Não consta na tabela
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Outros
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# </tbody>
# <tfoot class="tb_total">
# <tr>
# <td>
#             Total
#           </td>
# <td>
#             7.631.762
#           </td>
# <td>
#             12.899.275
#           </td>
# </tr>
# </tfoot>
# </table>
# <div class="tb_font">
#       Fonte: C.I.E.F.  M.F. <br/> Elaboração: Loiva Maria Ribeiro de Mello  EMBRAPA/CNPUV <br/>
# </div>
# <table class="tb_base tb_link no_print">
# <tr>
# <td>
# <a class="footer_content" href="download/ImpFrescas.csv" target="_blank">
# <img alt="" height="16" src="figures/download.png" width="16"/>
# <span class="spn_small">DOWNLOAD</span>
# </a>
# </td>
# <td class="footer_right">
# <a class="footer_content" href="#_top">
# <img alt="" height="16" src="figures/topo.png" width="16"/>
# <span class="spn_small">TOPO</span>
# </a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <table class="tb_base tb_footer">
# <tr>
# <td>
#                 Copyright © Embrapa Uva e Vinho. Todos os direitos reservados.<br/>
#                 Mais informações: <a class="footer_sac" href="https://www.embrapa.br/fale-conosco/sac">https://www.embrapa.br/fale-conosco/sac</a><br/>
#                 Última modificação: 21/12/23
#               </td>
# <td class="footer_right">
#                 Rua Livramento 515, Caixa Postal 130<br/>
#                 95700-000 Bento Gonçalves, RS - Brasil<br/>
#                 Fone: (54) 3455-8000 - Fax: (54) 3451-2792
#               </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# </body>
# </html>

# %%
json = {}
total = 0
for soup in soups:
    current_json = get_json2(soup)
    total += current_json["total"]
    json[current_json["titulo"]] = current_json
json["total"]=total
json
# Out:
# {'Importação de vinhos de mesa [2023]': {'titulo': 'Importação de vinhos de mesa [2023]',
#   'total': 137712871,
#   'tipo': [{'pais': 'Africa do Sul', 'qtd': 522733, 'valor': 1732850},
#    {'pais': 'Alemanha', 'qtd': 102456, 'valor': 557947},
#    {'pais': 'Argélia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Arábia Saudita', 'qtd': 8, 'valor': 161},
#    {'pais': 'Argentina', 'qtd': 25276991, 'valor': 83918138},
#    {'pais': 'Armênia', 'qtd': 3542, 'valor': 24336},
#    {'pais': 'Austrália', 'qtd': 432829, 'valor': 1568550},
#    {'pais': 'Áustria', 'qtd': 16832, 'valor': 145475},
#    {'pais': 'Bermudas', 'qtd': 6, 'valor': 879},
#    {'pais': 'Bélgica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bolívia', 'qtd': 1170, 'valor': 10920},
#    {'pais': 'Bósnia-Herzegovina', 'qtd': 0, 'valor': 0},
#    {'pais': 'Brasil', 'qtd': 6229, 'valor': 76894},
#    {'pais': 'Bulgária', 'qtd': 40281, 'valor': 95232},
#    {'pais': 'Canada', 'qtd': 14, 'valor': 1062},
#    {'pais': 'Chile', 'qtd': 62358765, 'valor': 170146247},
#    {'pais': 'China', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coreia do Sul, República', 'qtd': 0, 'valor': 0},
#    {'pais': 'Croácia', 'qtd': 1107, 'valor': 9160},
#    {'pais': 'Cuba', 'qtd': 8, 'valor': 261},
#    {'pais': 'Emirados Árabes Unidos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Eslovênia', 'qtd': 28806, 'valor': 124283},
#    {'pais': 'Eslováquia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 6591628, 'valor': 20097228},
#    {'pais': 'Estados Unidos', 'qtd': 244276, 'valor': 1775713},
#    {'pais': 'França', 'qtd': 4899631, 'valor': 30421272},
#    {'pais': 'Geórgia', 'qtd': 17173, 'valor': 29084},
#    {'pais': 'Geórgia do Sul e Sandwich do Sul, Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Grécia', 'qtd': 45889, 'valor': 147724},
#    {'pais': 'Hong Kong', 'qtd': 0, 'valor': 0},
#    {'pais': 'Hungria', 'qtd': 41905, 'valor': 316481},
#    {'pais': 'Indonésia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irlanda', 'qtd': 0, 'valor': 0},
#    {'pais': 'Israel', 'qtd': 48772, 'valor': 259405},
#    {'pais': 'Itália', 'qtd': 8868133, 'valor': 34760596},
#    {'pais': 'Japão', 'qtd': 86, 'valor': 3427},
#    {'pais': 'Iugoslávia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Líbano', 'qtd': 14328, 'valor': 106610},
#    {'pais': 'Luxemburgo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Macedônia', 'qtd': 8522, 'valor': 17172},
#    {'pais': 'Marrocos', 'qtd': 603, 'valor': 2349},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Moldávia', 'qtd': 51189, 'valor': 138741},
#    {'pais': 'Montenegro', 'qtd': 0, 'valor': 0},
#    {'pais': 'Noruega', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nova Zelândia', 'qtd': 28665, 'valor': 254138},
#    {'pais': 'Países Baixos (Holanda)', 'qtd': 9, 'valor': 354},
#    {'pais': 'Panamá', 'qtd': 0, 'valor': 0},
#    {'pais': 'Paraguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Peru', 'qtd': 12276, 'valor': 58862},
#    {'pais': 'Porto Rico', 'qtd': 2021, 'valor': 4481},
#    {'pais': 'Portugal', 'qtd': 25099409, 'valor': 71970948},
#    {'pais': 'Reino Unido', 'qtd': 1808, 'valor': 32757},
#    {'pais': 'Republica Dominicana', 'qtd': 0, 'valor': 0},
#    {'pais': 'Romênia', 'qtd': 36775, 'valor': 98835},
#    {'pais': 'Rússia', 'qtd': 0, 'valor': 0},
#    {'pais': 'San Marino', 'qtd': 0, 'valor': 0},
#    {'pais': 'Sérvia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Síria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suazilândia', 'qtd': 320, 'valor': 6968},
#    {'pais': 'Suíça', 'qtd': 2109, 'valor': 101111},
#    {'pais': 'Tcheca, República', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tunísia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Ucrânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uruguai', 'qtd': 2905567, 'valor': 9276001},
#    {'pais': 'Não consta na tabela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Não declarados', 'qtd': 0, 'valor': 0},
#    {'pais': 'Outros', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 137712871, 'valor': 428292652}]},
#  'Importação de espumantes [2023]': {'titulo': 'Importação de espumantes [2023]',
#   'total': 7347060,
#   'tipo': [{'pais': 'Africa do Sul', 'qtd': 7650, 'valor': 69382},
#    {'pais': 'Alemanha', 'qtd': 322, 'valor': 5111},
#    {'pais': 'Argentina', 'qtd': 839006, 'valor': 2765843},
#    {'pais': 'Austrália', 'qtd': 3150, 'valor': 10474},
#    {'pais': 'Áustria', 'qtd': 882, 'valor': 8833},
#    {'pais': 'Bermudas', 'qtd': 3, 'valor': 54},
#    {'pais': 'Bahamas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bélgica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Brasil', 'qtd': 7, 'valor': 184},
#    {'pais': 'Bulgária', 'qtd': 0, 'valor': 0},
#    {'pais': 'Canada', 'qtd': 23, 'valor': 279},
#    {'pais': 'Chile', 'qtd': 592991, 'valor': 1952709},
#    {'pais': 'Croácia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cuba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Emirados Árabes Unidos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Eslovênia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 3438264, 'valor': 9801916},
#    {'pais': 'Estados Unidos', 'qtd': 259, 'valor': 10273},
#    {'pais': 'França', 'qtd': 1401753, 'valor': 20166147},
#    {'pais': 'Geórgia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Granada', 'qtd': 2, 'valor': 40},
#    {'pais': 'Grécia', 'qtd': 300, 'valor': 1757},
#    {'pais': 'Hong Kong', 'qtd': 0, 'valor': 0},
#    {'pais': 'Hungria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Indonésia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irlanda', 'qtd': 0, 'valor': 0},
#    {'pais': 'Israel', 'qtd': 0, 'valor': 0},
#    {'pais': 'Itália', 'qtd': 952639, 'valor': 3533749},
#    {'pais': 'Japão', 'qtd': 0, 'valor': 0},
#    {'pais': 'Luxemburgo', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Moldávia', 'qtd': 955, 'valor': 1165},
#    {'pais': 'Nova Zelândia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Países Baixos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Panamá', 'qtd': 0, 'valor': 0},
#    {'pais': 'Peru', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 95326, 'valor': 386265},
#    {'pais': 'Reino Unido', 'qtd': 1507, 'valor': 28581},
#    {'pais': 'Romênia', 'qtd': 743, 'valor': 3841},
#    {'pais': 'Suíça', 'qtd': 464, 'valor': 34430},
#    {'pais': 'Tunísia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Ucrânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uruguai', 'qtd': 10814, 'valor': 45704},
#    {'pais': 'Não consta na tabela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Não declarados', 'qtd': 0, 'valor': 0},
#    {'pais': 'Outros', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 7347060, 'valor': 38826737}]},
#  'Importação de uvas frescas [2023]': {'titulo': 'Importação de uvas frescas [2023]',
#   'total': 7631762,
#   'tipo': [{'pais': 'Argélia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 400781, 'valor': 525034},
#    {'pais': 'Brasil', 'qtd': 0, 'valor': 0},
#    {'pais': 'Chile', 'qtd': 6144949, 'valor': 9738753},
#    {'pais': 'Colômbia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Egito', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 0, 'valor': 0},
#    {'pais': 'Estados Unidos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Grécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Itália', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Peru', 'qtd': 1086032, 'valor': 2635488},
#    {'pais': 'Paraguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 0, 'valor': 0},
#    {'pais': 'Panamá', 'qtd': 0, 'valor': 0},
#    {'pais': 'Reino Unido', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uruguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Venezuela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Não consta na tabela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Outros', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 7631762, 'valor': 12899275}]},
#  'Importação de uvas passas [2023]': {'titulo': 'Importação de uvas passas [2023]',
#   'total': 31172775,
#   'tipo': [{'pais': 'Afeganistão', 'qtd': 0, 'valor': 0},
#    {'pais': 'África do Sul', 'qtd': 151500, 'valor': 397825},
#    {'pais': 'Alemanha, República Democrática', 'qtd': 0, 'valor': 0},
#    {'pais': 'Arábia Saudita', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 19758017, 'valor': 36404746},
#    {'pais': 'Austrália', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bélgica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Chile', 'qtd': 4411180, 'valor': 7107544},
#    {'pais': 'China', 'qtd': 72000, 'valor': 111390},
#    {'pais': 'China Continental', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cingapura', 'qtd': 0, 'valor': 0},
#    {'pais': 'Costa Rica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Emirados', 'qtd': 0, 'valor': 0},
#    {'pais': 'Egito', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 0, 'valor': 0},
#    {'pais': 'Estados Unidos', 'qtd': 7578, 'valor': 58262},
#    {'pais': 'França', 'qtd': 0, 'valor': 0},
#    {'pais': 'Grécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guiana Britânica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Índia', 'qtd': 1293900, 'valor': 1379545},
#    {'pais': 'Irã', 'qtd': 786500, 'valor': 1832934},
#    {'pais': 'Itália', 'qtd': 0, 'valor': 0},
#    {'pais': 'Japão', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Países Baixos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Paraguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Peru', 'qtd': 25000, 'valor': 40630},
#    {'pais': 'Portugal', 'qtd': 0, 'valor': 0},
#    {'pais': 'Reino Unido', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 2621500, 'valor': 4152236},
#    {'pais': 'Uruguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uzbequistão', 'qtd': 2045600, 'valor': 2433719},
#    {'pais': 'Venezuela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Não consta na tabela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Outros', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 31172775, 'valor': 53918831}]},
#  'Importação de suco de uva [2023]': {'titulo': 'Importação de suco de uva [2023]',
#   'total': 30463,
#   'tipo': [{'pais': 'Africa do Sul', 'qtd': 0, 'valor': 0},
#    {'pais': 'Alemanha', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 0, 'valor': 0},
#    {'pais': 'Austria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Canadá', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coreia do Sul, República', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coreia do Norte, República', 'qtd': 0, 'valor': 0},
#    {'pais': 'Chile', 'qtd': 0, 'valor': 0},
#    {'pais': 'China', 'qtd': 0, 'valor': 0},
#    {'pais': 'Dinamarca', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 0, 'valor': 0},
#    {'pais': 'Estados Unidos', 'qtd': 28627, 'valor': 15200},
#    {'pais': 'França', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guiana', 'qtd': 0, 'valor': 0},
#    {'pais': 'Israel', 'qtd': 0, 'valor': 0},
#    {'pais': 'itália', 'qtd': 1836, 'valor': 1966},
#    {'pais': 'Japão', 'qtd': 0, 'valor': 0},
#    {'pais': 'Líbano', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Países Baixos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Panamá', 'qtd': 0, 'valor': 0},
#    {'pais': 'Peru', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 0, 'valor': 0},
#    {'pais': 'Reino Unido', 'qtd': 0, 'valor': 0},
#    {'pais': 'Taiwan', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uruguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Venezuela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Outros', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 30463, 'valor': 17166}]},
#  'total': 183894931}

# %% [markdown]
# ## EXPORTAÇÃO

# %%
# Ano: [1970-2023]
ano = 2023

# %%
soups = []
for i in range(1,6):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_06&subopcao=subopt_0{i}"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")
    soups.append(soup)
soups[2]
# Out:
# <!-- versão 2.00 -->
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# <head>
# <meta charset="utf-8"/>
# <meta content="Na página 'Vitibrasil' são apresentadas informações referentes à quantidade de uvas processadas, produção e comercialização de vinhos, suco e derivados provenientes do Estado do Rio Grande do Sul, que representa mais de 90% da produção nacional. Também são apresentados os dados de importações e exportações dos produtos da vitivinicultura." name="description"/>
# <meta content="Vinhos, Espumante, Uva, Uvas passas, Suco de uva, Produção, Processamento, Comercialização, Importação, Exportação, Publicação" lang="pt-BR" name="keywords"/>
# <meta content="Embrapa Uva e Vinho" name="author"/>
# <link href="./figures/favicon.ico" rel="Shortcut Icon"/>
# <link href="vitibrasil.css" rel="stylesheet" type="text/css"/>
# <title>Banco de dados de uva, vinho e derivados</title>
# <script>
#     var x = screen.width;
#     window.onload = function() {
#       var meta = document.createElement('meta');
#       meta.name = "viewport";
#       if(x < 780) {
#         var val = x/780;
#         meta.content = 'width=device-width, initial-scale=' + val;
#       }
#       else {
#         meta.content = 'width=device-width, initial-scale=1.0';
#       }
#       document.getElementsByTagName('head')[0].appendChild(meta);
#     }
#   </script>
# <!-- Piwik -->
# <script type="text/javascript">
#     var _paq = _paq || [];
#     _paq.push(['trackPageView']);
#     _paq.push(['enableLinkTracking']);
#     (function() {
#       var u=(("https:" == document.location.protocol) ? "https" : "http") + "://hotsites.cnpuv.embrapa.br/estatisticas/";
#       _paq.push(['setTrackerUrl', u+'piwik.php']);
#       _paq.push(['setSiteId', 3]);
#       var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript';
#       g.defer=true; g.async=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
#   </script>
# <noscript><p><img alt="" src="http://hotsites.cnpuv.embrapa.br/estatisticas/piwik.php?idsite=3" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </head>
# <body>
# <table class="tb_layout" id="_top">
# <tr>
# <td> </td>
# <td class="col_center" id="td_center">
# <table class="tb_base">
# <tr>
# <td>
# <p id="program_title">Dados da Vitivinicultura</p>
# </td>
# <td>
# <p id="program_mail">
# <a href="mailto:loiva.mello@embrapa.br">Loiva Maria Ribeiro de Mello</a>
# <br/>
# <a href="mailto:carlos.machado@embrapa.br">Carlos Alberto Ely Machado</a>
# </p>
# </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_layout">
# <tr>
# <td id="tb_banner"></td>
# </tr>
# </table>
# <table class="tb_layout no_print">
# <tr>
# <td> </td>
# <td class="col_center" id="row_height">
# <form action="index.php" method="get">
# <p id="row_btn">
# <button class="btn_opt" name="opcao" type="submit" value="opt_01">Apresentação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_02">Produção</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_03">Processamento</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_04">Comercialização</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_05">Importação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_06">Exportação</button>
# <button class="btn_opt" name="opcao" type="submit" value="opt_07">Publicação</button>
# </p>
# </form>
# <script>
#             var btn = 'opt_06';
#             var item = document.querySelector('button[value=' + btn + ']');
#             item.setAttribute('id','btn_active');
#           </script>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <div class="div_content">
# <p class="subtitle_1">Banco de dados de uva, vinho e derivados</p>
# <p class="subtitle_2">Exportação de derivados de uva</p>
# <table class="tb_base tb_header no_print">
# <tr>
# <td>
# <form action="index.php" method="get">
# <p>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_01">Vinhos de mesa</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_02">Espumantes</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_03">Uvas frescas</button><br/>
# <button class="btn_sopt" name="subopcao" type="submit" value="subopt_04">Suco de uva</button><br/>
# <input name="opcao" type="hidden" value="opt_06"/>
# </p>
# </form>
# <script>
#             var btn1 = 'subopt_03';
#             var item1 = document.querySelector('button[value=' + btn1 + ']');
#             item1.setAttribute('id','btn1_active');
#           </script>
# </td>
# <td>
# <form action="index.php">
# <p id="p_navegano">
# <button name="ano" type="submit" value="1970">«</button>
# <button name="ano" onclick="if(this.value&lt;1970){this.value=1970}" type="submit" value="2022">‹</button>
# <button disabled="disabled" id="neutral"> </button>
# <button name="ano" onclick="if(this.value&gt;2024){this.value=2024}" type="submit" value="2024">›</button>
# <button name="ano" type="submit" value="2024">»</button>
# <input name="opcao" type="hidden" value="opt_06"/>
# <input name="subopcao" type="hidden" value="subopt_03"/>
# </p>
# </form>
# </td>
# <td>
# <form action="index.php">
# <p id="p_ano">
# <label class="lbl_pesq">Ano: [1970-2024] </label> <br/>
# <input autocomplete="off" class="text_pesq" max="2024" min="1970" name="ano" onkeydown="return event.keyCode !== 69" required="" type="number" value=""/>
#               <input class="subm_pesq" type="submit" value="Ok"/>
# <input name="opcao" type="hidden" value="opt_06"/>
# <input name="subopcao" type="hidden" value="subopt_03"/>
# </p>
# </form>
# </td>
# </tr>
# </table>
# <div class="content_center">
# <p class="text_center">Exportação de uvas frescas [2023] </p>
# <table class="tb_base tb_dados">
# <thead>
# <tr>
# <th>Países</th>
# <th>Quantidade (Kg)</th>
# <th>Valor (US$)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
#             Africa do Sul
#           </td>
# <td>
#                     30
#                   </td>
# <td>
#                     136
#                   </td>
# </tr>
# <tr>
# <td>
#             Alemanha, República Democrática
#           </td>
# <td>
#                     1.701.887
#                   </td>
# <td>
#                     4.101.648
#                   </td>
# </tr>
# <tr>
# <td>
#             Angola
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Antígua e Barbuda
#           </td>
# <td>
#                     260
#                   </td>
# <td>
#                     1.173
#                   </td>
# </tr>
# <tr>
# <td>
#             Arabia Saudita
#           </td>
# <td>
#                     2.234
#                   </td>
# <td>
#                     19.382
#                   </td>
# </tr>
# <tr>
# <td>
#             Argélia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Argentina
#           </td>
# <td>
#                     2.265.038
#                   </td>
# <td>
#                     5.234.176
#                   </td>
# </tr>
# <tr>
# <td>
#             Áustria
#           </td>
# <td>
#                     20
#                   </td>
# <td>
#                     41
#                   </td>
# </tr>
# <tr>
# <td>
#             Bahamas
#           </td>
# <td>
#                     4.871
#                   </td>
# <td>
#                     19.408
#                   </td>
# </tr>
# <tr>
# <td>
#             Bahrein
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Bangladesh
#           </td>
# <td>
#                     141
#                   </td>
# <td>
#                     402
#                   </td>
# </tr>
# <tr>
# <td>
#             Barbados
#           </td>
# <td>
#                     237
#                   </td>
# <td>
#                     874
#                   </td>
# </tr>
# <tr>
# <td>
#             Barein
#           </td>
# <td>
#                     622
#                   </td>
# <td>
#                     2.602
#                   </td>
# </tr>
# <tr>
# <td>
#             Bélgica
#           </td>
# <td>
#                     254
#                   </td>
# <td>
#                     1.056
#                   </td>
# </tr>
# <tr>
# <td>
#             Belize
#           </td>
# <td>
#                     52
#                   </td>
# <td>
#                     125
#                   </td>
# </tr>
# <tr>
# <td>
#             Bermudas
#           </td>
# <td>
#                     194
#                   </td>
# <td>
#                     821
#                   </td>
# </tr>
# <tr>
# <td>
#             Bolívia
#           </td>
# <td>
#                     261.712
#                   </td>
# <td>
#                     151.770
#                   </td>
# </tr>
# <tr>
# <td>
#             Bósnia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Brasil
#           </td>
# <td>
#                     170
#                   </td>
# <td>
#                     470
#                   </td>
# </tr>
# <tr>
# <td>
#             Bulgária
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Burquina Faso
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Cabo Verde
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Camarões
#           </td>
# <td>
#                     10
#                   </td>
# <td>
#                     66
#                   </td>
# </tr>
# <tr>
# <td>
#             Camores
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Canadá
#           </td>
# <td>
#                     1.175.975
#                   </td>
# <td>
#                     3.667.725
#                   </td>
# </tr>
# <tr>
# <td>
#             Catar
#           </td>
# <td>
#                     2.210
#                   </td>
# <td>
#                     6.616
#                   </td>
# </tr>
# <tr>
# <td>
#             Cayman, Ilhas
#           </td>
# <td>
#                     278
#                   </td>
# <td>
#                     1.007
#                   </td>
# </tr>
# <tr>
# <td>
#             Chile
#           </td>
# <td>
#                     10
#                   </td>
# <td>
#                     38
#                   </td>
# </tr>
# <tr>
# <td>
#             China
#           </td>
# <td>
#                     1.210
#                   </td>
# <td>
#                     5.500
#                   </td>
# </tr>
# <tr>
# <td>
#             Chipre
#           </td>
# <td>
#                     1.633
#                   </td>
# <td>
#                     5.538
#                   </td>
# </tr>
# <tr>
# <td>
#             Cingapura
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Cocos (Keeling), Ilhas
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Cook, Ilhas
#           </td>
# <td>
#                     116
#                   </td>
# <td>
#                     839
#                   </td>
# </tr>
# <tr>
# <td>
#             Colômbia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Congo
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Coreia do Norte
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Coreia do Sul
#           </td>
# <td>
#                     366
#                   </td>
# <td>
#                     1.376
#                   </td>
# </tr>
# <tr>
# <td>
#             Costa do Marfim
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Coveite
#           </td>
# <td>
#                     3.725
#                   </td>
# <td>
#                     22.339
#                   </td>
# </tr>
# <tr>
# <td>
#             Croácia
#           </td>
# <td>
#                     5
#                   </td>
# <td>
#                     12
#                   </td>
# </tr>
# <tr>
# <td>
#             Curaçao
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Dinamarca
#           </td>
# <td>
#                     115.901
#                   </td>
# <td>
#                     264.623
#                   </td>
# </tr>
# <tr>
# <td>
#             Djibuti
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Egito
#           </td>
# <td>
#                     50
#                   </td>
# <td>
#                     153
#                   </td>
# </tr>
# <tr>
# <td>
#             Emirados Árabes Unidos
#           </td>
# <td>
#                     177.198
#                   </td>
# <td>
#                     672.359
#                   </td>
# </tr>
# <tr>
# <td>
#             Eslovênia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Espanha
#           </td>
# <td>
#                     4.177.500
#                   </td>
# <td>
#                     7.656.023
#                   </td>
# </tr>
# <tr>
# <td>
#             Estados Unidos
#           </td>
# <td>
#                     19.529.155
#                   </td>
# <td>
#                     58.146.305
#                   </td>
# </tr>
# <tr>
# <td>
#             Falkland (Ilhas Malvinas)
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Faroé, Ilhas
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Filipinas
#           </td>
# <td>
#                     171
#                   </td>
# <td>
#                     530
#                   </td>
# </tr>
# <tr>
# <td>
#             Finlândia
#           </td>
# <td>
#                     1
#                   </td>
# <td>
#                     21
#                   </td>
# </tr>
# <tr>
# <td>
#             França
#           </td>
# <td>
#                     428
#                   </td>
# <td>
#                     2.040
#                   </td>
# </tr>
# <tr>
# <td>
#             Gabão
#           </td>
# <td>
#                     83
#                   </td>
# <td>
#                     316
#                   </td>
# </tr>
# <tr>
# <td>
#             Gana
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Georgia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Gibraltar
#           </td>
# <td>
#                     114
#                   </td>
# <td>
#                     472
#                   </td>
# </tr>
# <tr>
# <td>
#             Grécia
#           </td>
# <td>
#                     3.036
#                   </td>
# <td>
#                     9.131
#                   </td>
# </tr>
# <tr>
# <td>
#             Guadalupe
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Guiana
#           </td>
# <td>
#                     4.999
#                   </td>
# <td>
#                     17.249
#                   </td>
# </tr>
# <tr>
# <td>
#             Guiana Francesa
#           </td>
# <td>
#                     705
#                   </td>
# <td>
#                     3.500
#                   </td>
# </tr>
# <tr>
# <td>
#             Guiné-Bissau
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Guine Equatorial
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Honduras
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Hong Kong
#           </td>
# <td>
#                     27.717
#                   </td>
# <td>
#                     136.684
#                   </td>
# </tr>
# <tr>
# <td>
#             Ilha de Man
#           </td>
# <td>
#                     311
#                   </td>
# <td>
#                     1.282
#                   </td>
# </tr>
# <tr>
# <td>
#             Ilhas Virgens
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Índia
#           </td>
# <td>
#                     510
#                   </td>
# <td>
#                     1.781
#                   </td>
# </tr>
# <tr>
# <td>
#             Indonésia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Irã
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Iraque
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Irlanda
#           </td>
# <td>
#                     629.421
#                   </td>
# <td>
#                     1.732.292
#                   </td>
# </tr>
# <tr>
# <td>
#             Islândia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Itália
#           </td>
# <td>
#                     29.040
#                   </td>
# <td>
#                     96.548
#                   </td>
# </tr>
# <tr>
# <td>
#             Japão
#           </td>
# <td>
#                     393
#                   </td>
# <td>
#                     1.413
#                   </td>
# </tr>
# <tr>
# <td>
#             Jérsei
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Jordânia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Letônia
#           </td>
# <td>
#                     44
#                   </td>
# <td>
#                     92
#                   </td>
# </tr>
# <tr>
# <td>
#             Líbano
#           </td>
# <td>
#                     147
#                   </td>
# <td>
#                     514
#                   </td>
# </tr>
# <tr>
# <td>
#             Libéria
#           </td>
# <td>
#                     13.876
#                   </td>
# <td>
#                     55.239
#                   </td>
# </tr>
# <tr>
# <td>
#             Líbia
#           </td>
# <td>
#                     5
#                   </td>
# <td>
#                     32
#                   </td>
# </tr>
# <tr>
# <td>
#             Lituânia
#           </td>
# <td>
#                     46.041
#                   </td>
# <td>
#                     117.335
#                   </td>
# </tr>
# <tr>
# <td>
#             Luxemburgo
#           </td>
# <td>
#                     24
#                   </td>
# <td>
#                     123
#                   </td>
# </tr>
# <tr>
# <td>
#             Macedônia
#           </td>
# <td>
#                     10
#                   </td>
# <td>
#                     42
#                   </td>
# </tr>
# <tr>
# <td>
#             Malásia
#           </td>
# <td>
#                     74
#                   </td>
# <td>
#                     335
#                   </td>
# </tr>
# <tr>
# <td>
#             Malta
#           </td>
# <td>
#                     5.282
#                   </td>
# <td>
#                     21.528
#                   </td>
# </tr>
# <tr>
# <td>
#             Marianas do Norte, Ilhas
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Marrocos
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Marshall, Ilhas
#           </td>
# <td>
#                     14.858
#                   </td>
# <td>
#                     59.743
#                   </td>
# </tr>
# <tr>
# <td>
#             Martinica
#           </td>
# <td>
#                     5
#                   </td>
# <td>
#                     37
#                   </td>
# </tr>
# <tr>
# <td>
#             Mauricio
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Mauritânia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Mexico
#           </td>
# <td>
#                     30
#                   </td>
# <td>
#                     78
#                   </td>
# </tr>
# <tr>
# <td>
#             Mônaco
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Mongólia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Montenegro
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Nigéria
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Noruega
#           </td>
# <td>
#                     464.880
#                   </td>
# <td>
#                     1.524.584
#                   </td>
# </tr>
# <tr>
# <td>
#             Omã
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Países Baixos
#           </td>
# <td>
#                     26.855.736
#                   </td>
# <td>
#                     62.427.840
#                   </td>
# </tr>
# <tr>
# <td>
#             Palau
#           </td>
# <td>
#                     115
#                   </td>
# <td>
#                     307
#                   </td>
# </tr>
# <tr>
# <td>
#             Panamá
#           </td>
# <td>
#                     15.613
#                   </td>
# <td>
#                     58.337
#                   </td>
# </tr>
# <tr>
# <td>
#             Paquistão
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Paraguai
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Pitcairn
#           </td>
# <td>
#                     17
#                   </td>
# <td>
#                     68
#                   </td>
# </tr>
# <tr>
# <td>
#             Polônia
#           </td>
# <td>
#                     66
#                   </td>
# <td>
#                     124
#                   </td>
# </tr>
# <tr>
# <td>
#             Porto Rico
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Portugal
#           </td>
# <td>
#                     14.824
#                   </td>
# <td>
#                     45.165
#                   </td>
# </tr>
# <tr>
# <td>
#             Quirguistão
#           </td>
# <td>
#                     20
#                   </td>
# <td>
#                     121
#                   </td>
# </tr>
# <tr>
# <td>
#             Reino Unido
#           </td>
# <td>
#                     15.358.148
#                   </td>
# <td>
#                     37.383.249
#                   </td>
# </tr>
# <tr>
# <td>
#             Republica Dominicana
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Romênia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Rússia,  Federação da
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Samoa Americana
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             São Cristóvão e Névis
#           </td>
# <td>
#                     36
#                   </td>
# <td>
#                     152
#                   </td>
# </tr>
# <tr>
# <td>
#             São Tomé e Príncipe
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             São Vicente e Granadinas
#           </td>
# <td>
#                     20
#                   </td>
# <td>
#                     83
#                   </td>
# </tr>
# <tr>
# <td>
#             Serra Leoa
#           </td>
# <td>
#                     2
#                   </td>
# <td>
#                     5
#                   </td>
# </tr>
# <tr>
# <td>
#             Senegal
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Singapura
#           </td>
# <td>
#                     15.407
#                   </td>
# <td>
#                     100.508
#                   </td>
# </tr>
# <tr>
# <td>
#             Sri Lanka
#           </td>
# <td>
#                     20
#                   </td>
# <td>
#                     30
#                   </td>
# </tr>
# <tr>
# <td>
#             Suazilândia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Suécia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Suíça
#           </td>
# <td>
#                     3.632
#                   </td>
# <td>
#                     53.106
#                   </td>
# </tr>
# <tr>
# <td>
#             Suriname
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Tailândia
#           </td>
# <td>
#                     794
#                   </td>
# <td>
#                     3.413
#                   </td>
# </tr>
# <tr>
# <td>
#             Taiwan
#           </td>
# <td>
#                     83
#                   </td>
# <td>
#                     293
#                   </td>
# </tr>
# <tr>
# <td>
#             Tanzânia
#           </td>
# <td>
#                     19
#                   </td>
# <td>
#                     76
#                   </td>
# </tr>
# <tr>
# <td>
#             Togo
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Trindade e Tobago
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Tunísia
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Turcas e Caicos, ilhas
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Turquia
#           </td>
# <td>
#                     334
#                   </td>
# <td>
#                     976
#                   </td>
# </tr>
# <tr>
# <td>
#             Tuvalu
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Uruguai
#           </td>
# <td>
#                     281.594
#                   </td>
# <td>
#                     547.227
#                   </td>
# </tr>
# <tr>
# <td>
#             Vanuatu
#           </td>
# <td>
#                     31
#                   </td>
# <td>
#                     88
#                   </td>
# </tr>
# <tr>
# <td>
#             Venezuela
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Vietnã
#           </td>
# <td>
#                     63
#                   </td>
# <td>
#                     177
#                   </td>
# </tr>
# <tr>
# <td>
#             Wallis e Futuna, Ilhas
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# <tr>
# <td>
#             Provisão de Navios e Aeronaves
#           </td>
# <td>-</td>
# <td>-</td>
# </tr>
# </tbody>
# <tfoot class="tb_total">
# <tr>
# <td>
#             Total
#           </td>
# <td>
#             73.211.843
#           </td>
# <td>
#             184.388.889
#           </td>
# </tr>
# </tfoot>
# </table>
# <div class="tb_font">
#       Fonte: CACEX e DECEX/C.T.I.C. <br/> Elaboração: Loiva Maria Ribeiro de Mello - EMBRAPA/CNPUV <br/>
# </div>
# <table class="tb_base tb_link no_print">
# <tr>
# <td>
# <a class="footer_content" href="download/ExpUva.csv" target="_blank">
# <img alt="" height="16" src="figures/download.png" width="16"/>
# <span class="spn_small">DOWNLOAD</span>
# </a>
# </td>
# <td class="footer_right">
# <a class="footer_content" href="#_top">
# <img alt="" height="16" src="figures/topo.png" width="16"/>
# <span class="spn_small">TOPO</span>
# </a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </td>
# <td> </td>
# </tr>
# </table>
# <table class="tb_base">
# <tr>
# <td> </td>
# <td class="col_center">
# <table class="tb_base tb_footer">
# <tr>
# <td>
#                 Copyright © Embrapa Uva e Vinho. Todos os direitos reservados.<br/>
#                 Mais informações: <a class="footer_sac" href="https://www.embrapa.br/fale-conosco/sac">https://www.embrapa.br/fale-conosco/sac</a><br/>
#                 Última modificação: 21/12/23
#               </td>
# <td class="footer_right">
#                 Rua Livramento 515, Caixa Postal 130<br/>
#                 95700-000 Bento Gonçalves, RS - Brasil<br/>
#                 Fone: (54) 3455-8000 - Fax: (54) 3451-2792
#               </td>
# </tr>
# </table>
# </td>
# <td> </td>
# </tr>
# </table>
# </body>
# </html>

# %%
json = {}
total = 0
for soup in soups:
    current_json = get_json2(soup)
    total += current_json["total"]
    json[current_json["titulo"]] = current_json
json["total"]=total
json
# Out:
# {'Exportação de vinhos de mesa': {'titulo': 'Exportação de vinhos de mesa',
#   'ano': 2023,
#   'total': 5538888,
#   'tipo': [{'pais': 'Afeganistão', 'qtd': 0, 'valor': 0},
#    {'pais': 'África do Sul', 'qtd': 117, 'valor': 698},
#    {'pais': 'Alemanha, República Democrática', 'qtd': 4806, 'valor': 31853},
#    {'pais': 'Angola', 'qtd': 0, 'valor': 0},
#    {'pais': 'Anguilla', 'qtd': 0, 'valor': 0},
#    {'pais': 'Antígua e Barbuda', 'qtd': 383, 'valor': 1848},
#    {'pais': 'Antilhas Holandesas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Arábia Saudita', 'qtd': 124, 'valor': 142},
#    {'pais': 'Argélia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 4545, 'valor': 36133},
#    {'pais': 'Aruba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Austrália', 'qtd': 2485, 'valor': 13565},
#    {'pais': 'Áustria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bahamas', 'qtd': 1348, 'valor': 7402},
#    {'pais': 'Bangladesh', 'qtd': 0, 'valor': 0},
#    {'pais': 'Barbados', 'qtd': 58, 'valor': 303},
#    {'pais': 'Barein', 'qtd': 283, 'valor': 1684},
#    {'pais': 'Bélgica', 'qtd': 95, 'valor': 683},
#    {'pais': 'Belice', 'qtd': 0, 'valor': 0},
#    {'pais': 'Benin', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bermudas', 'qtd': 16, 'valor': 153},
#    {'pais': 'Bolívia', 'qtd': 21926, 'valor': 36950},
#    {'pais': 'Bósnia-Herzegovina', 'qtd': 0, 'valor': 0},
#    {'pais': 'Brasil', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bulgária', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cabo Verde', 'qtd': 0, 'valor': 0},
#    {'pais': 'Camarões', 'qtd': 0, 'valor': 0},
#    {'pais': 'Canadá', 'qtd': 11539, 'valor': 42179},
#    {'pais': 'Catar', 'qtd': 5, 'valor': 18},
#    {'pais': 'Cayman, Ilhas', 'qtd': 438, 'valor': 2632},
#    {'pais': 'Chile', 'qtd': 9, 'valor': 63},
#    {'pais': 'China', 'qtd': 73917, 'valor': 183096},
#    {'pais': 'Chipre', 'qtd': 524, 'valor': 2995},
#    {'pais': 'Cingapura', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cocos (Keeling), Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Colômbia', 'qtd': 450, 'valor': 1259},
#    {'pais': 'Comores', 'qtd': 0, 'valor': 0},
#    {'pais': 'Congo', 'qtd': 17100, 'valor': 26600},
#    {'pais': 'Coreia, Republica Sul', 'qtd': 25, 'valor': 171},
#    {'pais': 'Costa do Marfim', 'qtd': 0, 'valor': 0},
#    {'pais': 'Costa Rica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coveite (Kuweit)', 'qtd': 0, 'valor': 0},
#    {'pais': 'Croácia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cuba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Curaçao', 'qtd': 25135, 'valor': 40807},
#    {'pais': 'Dinamarca', 'qtd': 1734, 'valor': 15261},
#    {'pais': 'Dominica', 'qtd': 0, 'valor': 0},
#    {'pais': 'El Salvador', 'qtd': 0, 'valor': 0},
#    {'pais': 'Emirados Arabes Unidos', 'qtd': 1417, 'valor': 6762},
#    {'pais': 'Equador', 'qtd': 2790, 'valor': 4392},
#    {'pais': 'Eslovaca, Republica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 180, 'valor': 4171},
#    {'pais': 'Estados Unidos', 'qtd': 229839, 'valor': 429091},
#    {'pais': 'Estônia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Filipinas', 'qtd': 94, 'valor': 334},
#    {'pais': 'Finlândia', 'qtd': 5, 'valor': 11},
#    {'pais': 'França', 'qtd': 2265, 'valor': 14722},
#    {'pais': 'Gabão', 'qtd': 0, 'valor': 0},
#    {'pais': 'Gana', 'qtd': 7237, 'valor': 29473},
#    {'pais': 'Gibraltar', 'qtd': 0, 'valor': 0},
#    {'pais': 'Granada', 'qtd': 0, 'valor': 0},
#    {'pais': 'Grécia', 'qtd': 1294, 'valor': 3214},
#    {'pais': 'Guatemala', 'qtd': 2053, 'valor': 3758},
#    {'pais': 'Guiana', 'qtd': 33651, 'valor': 88715},
#    {'pais': 'Guiana Francesa', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guine Bissau', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guine Equatorial', 'qtd': 0, 'valor': 0},
#    {'pais': 'Haiti', 'qtd': 559645, 'valor': 871661},
#    {'pais': 'Honduras', 'qtd': 0, 'valor': 0},
#    {'pais': 'Hong Kong', 'qtd': 16255, 'valor': 71025},
#    {'pais': 'Hungria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Ilha de Man', 'qtd': 1428, 'valor': 4533},
#    {'pais': 'Ilhas Virgens', 'qtd': 0, 'valor': 0},
#    {'pais': 'Índia', 'qtd': 60, 'valor': 170},
#    {'pais': 'Indonésia', 'qtd': 9, 'valor': 30},
#    {'pais': 'Irã', 'qtd': 0, 'valor': 0},
#    {'pais': 'Iraque', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irlanda', 'qtd': 150, 'valor': 377},
#    {'pais': 'Itália', 'qtd': 2922, 'valor': 27665},
#    {'pais': 'Jamaica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Japão', 'qtd': 22942, 'valor': 57780},
#    {'pais': 'Jordânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Letônia', 'qtd': 8, 'valor': 8},
#    {'pais': 'Líbano', 'qtd': 0, 'valor': 0},
#    {'pais': 'Libéria', 'qtd': 39784, 'valor': 42463},
#    {'pais': 'Luxemburgo', 'qtd': 581, 'valor': 7048},
#    {'pais': 'Macau', 'qtd': 7, 'valor': 6},
#    {'pais': 'Malásia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Malavi', 'qtd': 3660, 'valor': 6252},
#    {'pais': 'Malta', 'qtd': 6561, 'valor': 24199},
#    {'pais': 'Marshall, Ilhas', 'qtd': 7417, 'valor': 31691},
#    {'pais': 'Martinica', 'qtd': 9, 'valor': 31},
#    {'pais': 'Mauritânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 3, 'valor': 19},
#    {'pais': 'Moçambique', 'qtd': 0, 'valor': 0},
#    {'pais': 'Montenegro', 'qtd': 0, 'valor': 0},
#    {'pais': 'Namíbia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nicarágua', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nigéria', 'qtd': 10800, 'valor': 16464},
#    {'pais': 'Noruega', 'qtd': 861, 'valor': 4243},
#    {'pais': 'Nova Caledônia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nova Zelândia', 'qtd': 338, 'valor': 7177},
#    {'pais': 'Omã', 'qtd': 0, 'valor': 0},
#    {'pais': 'Países Baixos', 'qtd': 2244, 'valor': 4958},
#    {'pais': 'Palau', 'qtd': 45, 'valor': 143},
#    {'pais': 'Panamá', 'qtd': 14785, 'valor': 68173},
#    {'pais': 'Paraguai', 'qtd': 3780378, 'valor': 5517263},
#    {'pais': 'Peru', 'qtd': 47277, 'valor': 84282},
#    {'pais': 'Pitcairn', 'qtd': 11, 'valor': 22},
#    {'pais': 'Polônia', 'qtd': 298, 'valor': 590},
#    {'pais': 'Porto Rico', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 13742, 'valor': 46311},
#    {'pais': 'Quênia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Reino Unido', 'qtd': 11326, 'valor': 84547},
#    {'pais': 'República Dominicana', 'qtd': 0, 'valor': 0},
#    {'pais': 'Rússia', 'qtd': 0, 'valor': 0},
#    {'pais': 'São Cristóvão e Névis', 'qtd': 16, 'valor': 31},
#    {'pais': 'São Tomé e Príncipe', 'qtd': 0, 'valor': 0},
#    {'pais': 'São Vicente e Granadinas', 'qtd': 39, 'valor': 139},
#    {'pais': 'Senegal', 'qtd': 0, 'valor': 0},
#    {'pais': 'Serra Leoa', 'qtd': 23200, 'valor': 38548},
#    {'pais': 'Sérvia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Singapura', 'qtd': 3941, 'valor': 19781},
#    {'pais': 'Suazilândia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suíça', 'qtd': 2500, 'valor': 28763},
#    {'pais': 'Suriname', 'qtd': 3105, 'valor': 5235},
#    {'pais': 'Tailândia', 'qtd': 189, 'valor': 1387},
#    {'pais': 'Taiwan (Formosa)', 'qtd': 4208, 'valor': 19998},
#    {'pais': 'Tanzânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tcheca, República', 'qtd': 405, 'valor': 3348},
#    {'pais': 'Togo', 'qtd': 14550, 'valor': 25235},
#    {'pais': 'Toquelau', 'qtd': 3, 'valor': 10},
#    {'pais': 'Trinidade Tobago', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tunísia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 28104, 'valor': 95421},
#    {'pais': 'Tuvalu', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uruguai', 'qtd': 326093, 'valor': 454271},
#    {'pais': 'Vanuatu', 'qtd': 0, 'valor': 0},
#    {'pais': 'Venezuela', 'qtd': 141030, 'valor': 220512},
#    {'pais': 'Vietnã', 'qtd': 72, 'valor': 128},
#    {'pais': 'Total', 'qtd': 5538888, 'valor': 8923076}]},
#  'Exportação de espumantes': {'titulo': 'Exportação de espumantes',
#   'ano': 2023,
#   'total': 502505,
#   'tipo': [{'pais': 'África do Sul', 'qtd': 2, 'valor': 44},
#    {'pais': 'Alemanha', 'qtd': 162, 'valor': 1542},
#    {'pais': 'Angola', 'qtd': 56242, 'valor': 315073},
#    {'pais': 'Antigua e Barbuda', 'qtd': 24, 'valor': 100},
#    {'pais': 'Antilhas Holandesas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 8593, 'valor': 73239},
#    {'pais': 'Aruba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Australia', 'qtd': 10, 'valor': 6},
#    {'pais': 'Bahamas', 'qtd': 65, 'valor': 268},
#    {'pais': 'Bangladesh', 'qtd': 0, 'valor': 0},
#    {'pais': 'Barbados', 'qtd': 32, 'valor': 219},
#    {'pais': 'Belgica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Benin', 'qtd': 3, 'valor': 19},
#    {'pais': 'Bermudas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bolívia', 'qtd': 11410, 'valor': 34481},
#    {'pais': 'Bósnia-Herzegovina', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bulgaria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cabo Verde', 'qtd': 0, 'valor': 0},
#    {'pais': 'Camarões', 'qtd': 0, 'valor': 0},
#    {'pais': 'Canada', 'qtd': 4068, 'valor': 15427},
#    {'pais': 'Catar', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cayman, Ilhas', 'qtd': 5, 'valor': 33},
#    {'pais': 'Chile', 'qtd': 3532, 'valor': 15875},
#    {'pais': 'China', 'qtd': 16285, 'valor': 47822},
#    {'pais': 'Chipre', 'qtd': 188, 'valor': 707},
#    {'pais': 'Cingapura', 'qtd': 0, 'valor': 0},
#    {'pais': 'Colombia', 'qtd': 1926, 'valor': 6898},
#    {'pais': 'Coreia do Sul, Republica da', 'qtd': 74, 'valor': 222},
#    {'pais': 'Costa Rica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cuba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Curaçao', 'qtd': 1288, 'valor': 6539},
#    {'pais': 'Dinamarca', 'qtd': 2790, 'valor': 26359},
#    {'pais': 'Djibuti', 'qtd': 0, 'valor': 0},
#    {'pais': 'Dominica', 'qtd': 0, 'valor': 0},
#    {'pais': 'El Salvador', 'qtd': 0, 'valor': 0},
#    {'pais': 'Emirados Arabes Unidos', 'qtd': 126, 'valor': 622},
#    {'pais': 'Equador', 'qtd': 540, 'valor': 2000},
#    {'pais': 'Espanha', 'qtd': 45, 'valor': 853},
#    {'pais': 'Estados Unidos', 'qtd': 255198, 'valor': 729055},
#    {'pais': 'Estonia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Falkland (Malvinas)', 'qtd': 0, 'valor': 0},
#    {'pais': 'Filipinas', 'qtd': 20, 'valor': 111},
#    {'pais': 'Filânldia', 'qtd': 180, 'valor': 1770},
#    {'pais': 'França', 'qtd': 0, 'valor': 0},
#    {'pais': 'Gana', 'qtd': 4719, 'valor': 35778},
#    {'pais': 'Gibraltar', 'qtd': 0, 'valor': 0},
#    {'pais': 'Granada', 'qtd': 0, 'valor': 0},
#    {'pais': 'Grécia', 'qtd': 59, 'valor': 320},
#    {'pais': 'Guatemala', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guiana', 'qtd': 14084, 'valor': 71163},
#    {'pais': 'Guiné Equatorial', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guiné-Bissau', 'qtd': 0, 'valor': 0},
#    {'pais': 'Haiti', 'qtd': 3969, 'valor': 10646},
#    {'pais': 'Honduras', 'qtd': 0, 'valor': 0},
#    {'pais': 'Hong Kong', 'qtd': 1355, 'valor': 5169},
#    {'pais': 'Hungria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Ilha de Man', 'qtd': 0, 'valor': 0},
#    {'pais': 'Índia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Iraque', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irlanda', 'qtd': 0, 'valor': 0},
#    {'pais': 'Islândia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Itália', 'qtd': 1460, 'valor': 19905},
#    {'pais': 'Japão', 'qtd': 2311, 'valor': 9708},
#    {'pais': 'Jordânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Letônia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Líbano', 'qtd': 0, 'valor': 0},
#    {'pais': 'Libéria', 'qtd': 973, 'valor': 3358},
#    {'pais': 'Luxemburgo', 'qtd': 18, 'valor': 305},
#    {'pais': 'Maldivas', 'qtd': 4577, 'valor': 20204},
#    {'pais': 'Malta', 'qtd': 1472, 'valor': 44498},
#    {'pais': 'Marrocos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Marshall, Ilhas', 'qtd': 1375, 'valor': 4886},
#    {'pais': 'Montenegro', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nicarágua', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nigéria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Noruega', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nova Zelândia', 'qtd': 303, 'valor': 4231},
#    {'pais': 'Países Baixos (Holanda)', 'qtd': 3, 'valor': 49},
#    {'pais': 'Panamá', 'qtd': 7936, 'valor': 43115},
#    {'pais': 'Paraguai', 'qtd': 64662, 'valor': 192975},
#    {'pais': 'Peru', 'qtd': 108, 'valor': 756},
#    {'pais': 'Polônia', 'qtd': 126, 'valor': 659},
#    {'pais': 'Porto Rico', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 2191, 'valor': 38616},
#    {'pais': 'Quênia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Reino Unido', 'qtd': 16057, 'valor': 86879},
#    {'pais': 'Republica Dominicana', 'qtd': 0, 'valor': 0},
#    {'pais': 'Republica Tcheca', 'qtd': 0, 'valor': 0},
#    {'pais': 'Rússia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Serra Leoa', 'qtd': 271, 'valor': 1287},
#    {'pais': 'Sérvia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Singapura', 'qtd': 209, 'valor': 599},
#    {'pais': 'Suécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suíça', 'qtd': 444, 'valor': 4474},
#    {'pais': 'Suriname', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tailândia', 'qtd': 7, 'valor': 43},
#    {'pais': 'Taiwan (Formosa)', 'qtd': 1099, 'valor': 3664},
#    {'pais': 'Tcheca, República', 'qtd': 167, 'valor': 1236},
#    {'pais': 'Togo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Trinidade e Tobago', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 6930, 'valor': 26566},
#    {'pais': 'Uruguai', 'qtd': 2812, 'valor': 14352},
#    {'pais': 'Vanuatu', 'qtd': 0, 'valor': 0},
#    {'pais': 'Venezuela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Vietnã', 'qtd': 0, 'valor': 0},
#    {'pais': 'Outros(1)', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 502505, 'valor': 1924725}]},
#  'Exportação de uvas frescas': {'titulo': 'Exportação de uvas frescas',
#   'ano': 2023,
#   'total': 73211843,
#   'tipo': [{'pais': 'Africa do Sul', 'qtd': 30, 'valor': 136},
#    {'pais': 'Alemanha, República Democrática',
#     'qtd': 1701887,
#     'valor': 4101648},
#    {'pais': 'Angola', 'qtd': 0, 'valor': 0},
#    {'pais': 'Antígua e Barbuda', 'qtd': 260, 'valor': 1173},
#    {'pais': 'Arabia Saudita', 'qtd': 2234, 'valor': 19382},
#    {'pais': 'Argélia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 2265038, 'valor': 5234176},
#    {'pais': 'Áustria', 'qtd': 20, 'valor': 41},
#    {'pais': 'Bahamas', 'qtd': 4871, 'valor': 19408},
#    {'pais': 'Bahrein', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bangladesh', 'qtd': 141, 'valor': 402},
#    {'pais': 'Barbados', 'qtd': 237, 'valor': 874},
#    {'pais': 'Barein', 'qtd': 622, 'valor': 2602},
#    {'pais': 'Bélgica', 'qtd': 254, 'valor': 1056},
#    {'pais': 'Belize', 'qtd': 52, 'valor': 125},
#    {'pais': 'Bermudas', 'qtd': 194, 'valor': 821},
#    {'pais': 'Bolívia', 'qtd': 261712, 'valor': 151770},
#    {'pais': 'Bósnia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Brasil', 'qtd': 170, 'valor': 470},
#    {'pais': 'Bulgária', 'qtd': 0, 'valor': 0},
#    {'pais': 'Burquina Faso', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cabo Verde', 'qtd': 0, 'valor': 0},
#    {'pais': 'Camarões', 'qtd': 10, 'valor': 66},
#    {'pais': 'Camores', 'qtd': 0, 'valor': 0},
#    {'pais': 'Canadá', 'qtd': 1175975, 'valor': 3667725},
#    {'pais': 'Catar', 'qtd': 2210, 'valor': 6616},
#    {'pais': 'Cayman, Ilhas', 'qtd': 278, 'valor': 1007},
#    {'pais': 'Chile', 'qtd': 10, 'valor': 38},
#    {'pais': 'China', 'qtd': 1210, 'valor': 5500},
#    {'pais': 'Chipre', 'qtd': 1633, 'valor': 5538},
#    {'pais': 'Cingapura', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cocos (Keeling), Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cook, Ilhas', 'qtd': 116, 'valor': 839},
#    {'pais': 'Colômbia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Congo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coreia do Norte', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coreia do Sul', 'qtd': 366, 'valor': 1376},
#    {'pais': 'Costa do Marfim', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coveite', 'qtd': 3725, 'valor': 22339},
#    {'pais': 'Croácia', 'qtd': 5, 'valor': 12},
#    {'pais': 'Curaçao', 'qtd': 0, 'valor': 0},
#    {'pais': 'Dinamarca', 'qtd': 115901, 'valor': 264623},
#    {'pais': 'Djibuti', 'qtd': 0, 'valor': 0},
#    {'pais': 'Egito', 'qtd': 50, 'valor': 153},
#    {'pais': 'Emirados Árabes Unidos', 'qtd': 177198, 'valor': 672359},
#    {'pais': 'Eslovênia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Espanha', 'qtd': 4177500, 'valor': 7656023},
#    {'pais': 'Estados Unidos', 'qtd': 19529155, 'valor': 58146305},
#    {'pais': 'Falkland (Ilhas Malvinas)', 'qtd': 0, 'valor': 0},
#    {'pais': 'Faroé, Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Filipinas', 'qtd': 171, 'valor': 530},
#    {'pais': 'Finlândia', 'qtd': 1, 'valor': 21},
#    {'pais': 'França', 'qtd': 428, 'valor': 2040},
#    {'pais': 'Gabão', 'qtd': 83, 'valor': 316},
#    {'pais': 'Gana', 'qtd': 0, 'valor': 0},
#    {'pais': 'Georgia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Gibraltar', 'qtd': 114, 'valor': 472},
#    {'pais': 'Grécia', 'qtd': 3036, 'valor': 9131},
#    {'pais': 'Guadalupe', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guiana', 'qtd': 4999, 'valor': 17249},
#    {'pais': 'Guiana Francesa', 'qtd': 705, 'valor': 3500},
#    {'pais': 'Guiné-Bissau', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guine Equatorial', 'qtd': 0, 'valor': 0},
#    {'pais': 'Honduras', 'qtd': 0, 'valor': 0},
#    {'pais': 'Hong Kong', 'qtd': 27717, 'valor': 136684},
#    {'pais': 'Ilha de Man', 'qtd': 311, 'valor': 1282},
#    {'pais': 'Ilhas Virgens', 'qtd': 0, 'valor': 0},
#    {'pais': 'Índia', 'qtd': 510, 'valor': 1781},
#    {'pais': 'Indonésia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irã', 'qtd': 0, 'valor': 0},
#    {'pais': 'Iraque', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irlanda', 'qtd': 629421, 'valor': 1732292},
#    {'pais': 'Islândia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Itália', 'qtd': 29040, 'valor': 96548},
#    {'pais': 'Japão', 'qtd': 393, 'valor': 1413},
#    {'pais': 'Jérsei', 'qtd': 0, 'valor': 0},
#    {'pais': 'Jordânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Letônia', 'qtd': 44, 'valor': 92},
#    {'pais': 'Líbano', 'qtd': 147, 'valor': 514},
#    {'pais': 'Libéria', 'qtd': 13876, 'valor': 55239},
#    {'pais': 'Líbia', 'qtd': 5, 'valor': 32},
#    {'pais': 'Lituânia', 'qtd': 46041, 'valor': 117335},
#    {'pais': 'Luxemburgo', 'qtd': 24, 'valor': 123},
#    {'pais': 'Macedônia', 'qtd': 10, 'valor': 42},
#    {'pais': 'Malásia', 'qtd': 74, 'valor': 335},
#    {'pais': 'Malta', 'qtd': 5282, 'valor': 21528},
#    {'pais': 'Marianas do Norte, Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Marrocos', 'qtd': 0, 'valor': 0},
#    {'pais': 'Marshall, Ilhas', 'qtd': 14858, 'valor': 59743},
#    {'pais': 'Martinica', 'qtd': 5, 'valor': 37},
#    {'pais': 'Mauricio', 'qtd': 0, 'valor': 0},
#    {'pais': 'Mauritânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Mexico', 'qtd': 30, 'valor': 78},
#    {'pais': 'Mônaco', 'qtd': 0, 'valor': 0},
#    {'pais': 'Mongólia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Montenegro', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nigéria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Noruega', 'qtd': 464880, 'valor': 1524584},
#    {'pais': 'Omã', 'qtd': 0, 'valor': 0},
#    {'pais': 'Países Baixos', 'qtd': 26855736, 'valor': 62427840},
#    {'pais': 'Palau', 'qtd': 115, 'valor': 307},
#    {'pais': 'Panamá', 'qtd': 15613, 'valor': 58337},
#    {'pais': 'Paquistão', 'qtd': 0, 'valor': 0},
#    {'pais': 'Paraguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Pitcairn', 'qtd': 17, 'valor': 68},
#    {'pais': 'Polônia', 'qtd': 66, 'valor': 124},
#    {'pais': 'Porto Rico', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 14824, 'valor': 45165},
#    {'pais': 'Quirguistão', 'qtd': 20, 'valor': 121},
#    {'pais': 'Reino Unido', 'qtd': 15358148, 'valor': 37383249},
#    {'pais': 'Republica Dominicana', 'qtd': 0, 'valor': 0},
#    {'pais': 'Romênia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Rússia,  Federação da', 'qtd': 0, 'valor': 0},
#    {'pais': 'Samoa Americana', 'qtd': 0, 'valor': 0},
#    {'pais': 'São Cristóvão e Névis', 'qtd': 36, 'valor': 152},
#    {'pais': 'São Tomé e Príncipe', 'qtd': 0, 'valor': 0},
#    {'pais': 'São Vicente e Granadinas', 'qtd': 20, 'valor': 83},
#    {'pais': 'Serra Leoa', 'qtd': 2, 'valor': 5},
#    {'pais': 'Senegal', 'qtd': 0, 'valor': 0},
#    {'pais': 'Singapura', 'qtd': 15407, 'valor': 100508},
#    {'pais': 'Sri Lanka', 'qtd': 20, 'valor': 30},
#    {'pais': 'Suazilândia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suíça', 'qtd': 3632, 'valor': 53106},
#    {'pais': 'Suriname', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tailândia', 'qtd': 794, 'valor': 3413},
#    {'pais': 'Taiwan', 'qtd': 83, 'valor': 293},
#    {'pais': 'Tanzânia', 'qtd': 19, 'valor': 76},
#    {'pais': 'Togo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Trindade e Tobago', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tunísia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turcas e Caicos, ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 334, 'valor': 976},
#    {'pais': 'Tuvalu', 'qtd': 0, 'valor': 0},
#    {'pais': 'Uruguai', 'qtd': 281594, 'valor': 547227},
#    {'pais': 'Vanuatu', 'qtd': 31, 'valor': 88},
#    {'pais': 'Venezuela', 'qtd': 0, 'valor': 0},
#    {'pais': 'Vietnã', 'qtd': 63, 'valor': 177},
#    {'pais': 'Wallis e Futuna, Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Provisão de Navios e Aeronaves', 'qtd': 0, 'valor': 0},
#    {'pais': 'Total', 'qtd': 73211843, 'valor': 184388889}]},
#  'Exportação de suco de uva': {'titulo': 'Exportação de suco de uva',
#   'ano': 2023,
#   'total': 5224898,
#   'tipo': [{'pais': 'África do Sul', 'qtd': 0, 'valor': 0},
#    {'pais': 'Alemanha, República Democrática da', 'qtd': 33, 'valor': 39},
#    {'pais': 'Angola', 'qtd': 55683, 'valor': 68724},
#    {'pais': 'Antígua e Barbuda', 'qtd': 0, 'valor': 0},
#    {'pais': 'Antilhas Holandesas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Arábia Saudita', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argélia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Argentina', 'qtd': 795, 'valor': 3808},
#    {'pais': 'Aruba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Austrália', 'qtd': 9228, 'valor': 20692},
#    {'pais': 'Áustria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bahamas', 'qtd': 463, 'valor': 674},
#    {'pais': 'Bangladesh', 'qtd': 302, 'valor': 352},
#    {'pais': 'Barbados', 'qtd': 187, 'valor': 545},
#    {'pais': 'Barein', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bélgica', 'qtd': 27, 'valor': 67},
#    {'pais': 'Belize', 'qtd': 0, 'valor': 0},
#    {'pais': 'Benin', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bermudas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Birmânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bolívia', 'qtd': 22246, 'valor': 31793},
#    {'pais': 'Brasil', 'qtd': 0, 'valor': 0},
#    {'pais': 'Bulgária', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cabo Verde', 'qtd': 90, 'valor': 170},
#    {'pais': 'Camarões', 'qtd': 0, 'valor': 0},
#    {'pais': 'Canadá', 'qtd': 29504, 'valor': 72670},
#    {'pais': 'Catar', 'qtd': 1, 'valor': 8},
#    {'pais': 'Cayman, Ilhas', 'qtd': 0, 'valor': 0},
#    {'pais': 'Chile', 'qtd': 3, 'valor': 6},
#    {'pais': 'China', 'qtd': 737608, 'valor': 1525476},
#    {'pais': 'Chipre', 'qtd': 156, 'valor': 40},
#    {'pais': 'Cingapura', 'qtd': 0, 'valor': 0},
#    {'pais': 'Colômbia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Congo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coreia do Sul', 'qtd': 46146, 'valor': 129150},
#    {'pais': 'Costa do Marfim', 'qtd': 0, 'valor': 0},
#    {'pais': 'Costa Rica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Coveite', 'qtd': 0, 'valor': 0},
#    {'pais': 'Cuba', 'qtd': 0, 'valor': 0},
#    {'pais': 'Curaçao', 'qtd': 336, 'valor': 1122},
#    {'pais': 'Dinamarca', 'qtd': 200, 'valor': 299},
#    {'pais': 'Dominica, Ilha de', 'qtd': 0, 'valor': 0},
#    {'pais': 'El Salvador', 'qtd': 0, 'valor': 0},
#    {'pais': 'Emirados Árabes Unidos', 'qtd': 1163, 'valor': 1213},
#    {'pais': 'Equador', 'qtd': 21876, 'valor': 30774},
#    {'pais': 'Espanha', 'qtd': 44592, 'valor': 25002},
#    {'pais': 'Estados Unidos', 'qtd': 866096, 'valor': 2125880},
#    {'pais': 'Falkland (Malvinas)', 'qtd': 0, 'valor': 0},
#    {'pais': 'Filipinas', 'qtd': 655, 'valor': 748},
#    {'pais': 'Finlândia', 'qtd': 0, 'valor': 0},
#    {'pais': 'França', 'qtd': 192, 'valor': 263},
#    {'pais': 'Gabão', 'qtd': 0, 'valor': 0},
#    {'pais': 'Gana', 'qtd': 103346, 'valor': 175088},
#    {'pais': 'Gibraltar', 'qtd': 0, 'valor': 0},
#    {'pais': 'Granada', 'qtd': 0, 'valor': 0},
#    {'pais': 'Grécia', 'qtd': 412, 'valor': 438},
#    {'pais': 'Guatemala', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guiana', 'qtd': 114, 'valor': 300},
#    {'pais': 'Guiana Francesa', 'qtd': 300, 'valor': 90},
#    {'pais': 'Guiné Bissau', 'qtd': 0, 'valor': 0},
#    {'pais': 'Guine Equatorial', 'qtd': 0, 'valor': 0},
#    {'pais': 'Haiti', 'qtd': 890, 'valor': 569},
#    {'pais': 'Hong Kong', 'qtd': 9236, 'valor': 14083},
#    {'pais': 'Hungria', 'qtd': 0, 'valor': 0},
#    {'pais': 'Ilha de Man', 'qtd': 144, 'valor': 202},
#    {'pais': 'India', 'qtd': 0, 'valor': 0},
#    {'pais': 'Indonésia', 'qtd': 2, 'valor': 3},
#    {'pais': 'Irã', 'qtd': 0, 'valor': 0},
#    {'pais': 'Iraque', 'qtd': 0, 'valor': 0},
#    {'pais': 'Irlanda', 'qtd': 930, 'valor': 2373},
#    {'pais': 'Israel', 'qtd': 0, 'valor': 0},
#    {'pais': 'Itália', 'qtd': 1655, 'valor': 1952},
#    {'pais': 'Iugoslâvia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Jamaica', 'qtd': 0, 'valor': 0},
#    {'pais': 'Japão', 'qtd': 2583100, 'valor': 6376989},
#    {'pais': 'Líbano', 'qtd': 16800, 'valor': 25432},
#    {'pais': 'Libéria', 'qtd': 1231, 'valor': 1737},
#    {'pais': 'Líbia', 'qtd': 74988, 'valor': 95805},
#    {'pais': 'Luxemburgo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Malásia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Malta', 'qtd': 1575, 'valor': 2007},
#    {'pais': 'Marshall, Ilhas', 'qtd': 2936, 'valor': 4694},
#    {'pais': 'Mauritânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'México', 'qtd': 0, 'valor': 0},
#    {'pais': 'Moçambique', 'qtd': 0, 'valor': 0},
#    {'pais': 'Mônaco', 'qtd': 0, 'valor': 0},
#    {'pais': 'Montenegro', 'qtd': 0, 'valor': 0},
#    {'pais': 'Namíbia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nigéria', 'qtd': 12390, 'valor': 16966},
#    {'pais': 'Noruega', 'qtd': 12, 'valor': 19},
#    {'pais': 'Nova Caledônia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Nova Zelândia', 'qtd': 6984, 'valor': 17987},
#    {'pais': 'Países Baixos', 'qtd': 36, 'valor': 55},
#    {'pais': 'Panamá', 'qtd': 11770, 'valor': 14148},
#    {'pais': 'Paquistão', 'qtd': 0, 'valor': 0},
#    {'pais': 'Paraguai', 'qtd': 319087, 'valor': 366822},
#    {'pais': 'Peru', 'qtd': 34700, 'valor': 73918},
#    {'pais': 'Polônia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Porto Rico', 'qtd': 0, 'valor': 0},
#    {'pais': 'Portugal', 'qtd': 79062, 'valor': 88208},
#    {'pais': 'Quênia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Reino Unido', 'qtd': 5290, 'valor': 13668},
#    {'pais': 'República Centro Africana', 'qtd': 0, 'valor': 0},
#    {'pais': 'República Dominicana', 'qtd': 25440, 'valor': 78719},
#    {'pais': 'República Federativa da Rússia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Rússia', 'qtd': 0, 'valor': 0},
#    {'pais': 'São Tomé e Príncipe', 'qtd': 0, 'valor': 0},
#    {'pais': 'Senegal', 'qtd': 0, 'valor': 0},
#    {'pais': 'Serra Leoa', 'qtd': 0, 'valor': 0},
#    {'pais': 'Singapura', 'qtd': 1749, 'valor': 3686},
#    {'pais': 'Sri Lanka', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suécia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suíça', 'qtd': 0, 'valor': 0},
#    {'pais': 'Suriname', 'qtd': 8480, 'valor': 23701},
#    {'pais': 'Tailândia', 'qtd': 24, 'valor': 37},
#    {'pais': 'Taiwan (Formosa)', 'qtd': 54173, 'valor': 132752},
#    {'pais': 'Tanzânia', 'qtd': 0, 'valor': 0},
#    {'pais': 'Tcheca, República', 'qtd': 0, 'valor': 0},
#    {'pais': 'Togo', 'qtd': 0, 'valor': 0},
#    {'pais': 'Toquelau', 'qtd': 24, 'valor': 39},
#    {'pais': 'Trinidade e Tobago', 'qtd': 0, 'valor': 0},
#    {'pais': 'Turquia', 'qtd': 230, 'valor': 455},
#    {'pais': 'Uruguai', 'qtd': 0, 'valor': 0},
#    {'pais': 'Vanuatu', 'qtd': 0, 'valor': 0},
#    {'pais': 'Venezuela', 'qtd': 30206, 'valor': 47287},
#    {'pais': 'Total', 'qtd': 5224898, 'valor': 11619744}]},
#  'Exportação de': {'titulo': 'Exportação de',
#   'ano': 2023,
#   'total': 0,
#   'tipo': [{'pais': 'Total', 'qtd': 0, 'valor': 0}]},
#  'total': 84478134}
